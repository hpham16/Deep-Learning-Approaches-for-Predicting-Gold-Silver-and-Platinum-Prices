# %% [markdown]
# # IS403.N22.HTCL
# ```python
# Team 16
# ```
# **SỬ DỤNG ĐỂ TÍNH TOÁN BỘ DỮ LIỆU GIÁ BẠCH KIM (19/05/2018 ĐẾN 19/05/2023)**
# - Tỷ lệ tính toán Train Data: 50% Dataset
# - Tỷ lệ tính toán Test Data: 30% Dataset
# - Tỷ lệ tính toán Validation Data: 20% Dataset

# %%
#Import các thư viện cần thiết
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from sklearn import preprocessing
from keras.layers import Conv1D,Flatten,MaxPooling1D,Bidirectional,LSTM,Dropout,TimeDistributed
from keras.layers import Dense,GlobalAveragePooling2D
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error,mean_absolute_error

# %%
#Đọc file dữ liệu và xem dữ liệu
df = pd.read_csv('../PlatiumData.csv',parse_dates=True)
df
# Out:
#            Ngày  Lần cuối      Mở     Cao    Thấp   KL
# 0     20/5/2018     886.2   886.8   889.0   885.5  NaN
# 1     21/5/2018     899.5   886.2   902.7   877.8  NaN
# 2     22/5/2018     908.3   899.5   912.0   896.3  NaN
# 3     23/5/2018     904.6   908.3   910.4   898.5  NaN
# 4     24/5/2018     910.4   904.6   914.7   903.5  NaN
# ...         ...       ...     ...     ...     ...  ...
# 1553  15/5/2023    1082.8  1057.6  1079.1  1057.5  NaN
# 1554  16/5/2023    1075.0  1070.5  1078.7  1061.8  NaN
# 1555  17/5/2023    1090.7  1067.7  1086.1  1067.4  NaN
# 1556  18/5/2023    1066.3  1079.2  1080.8  1055.0  NaN
# 1557  19/5/2023    1083.8  1059.6  1084.2  1055.0  NaN
#
# [1558 rows x 6 columns]

# %%
#Xem các dữ liệu cơ bản của cảc thuộc tính
df.describe()
# Out:
#           Lần cuối           Mở          Cao         Thấp
# count  1558.000000  1558.000000  1558.000000  1558.000000
# mean    944.065918   943.859884   955.499743   932.064955
# std     116.994315   116.800419   119.007199   115.160228
# min     595.200000   596.050000   615.400000   562.000000
# 25%     852.987500   852.887500   862.150000   844.275000
# 50%     930.875000   931.225000   941.900000   920.700000
# 75%    1018.200000  1017.575000  1029.475000  1003.175000
# max    1318.750000  1292.800000  1351.200000  1283.150000

# %%
#Kiểm tra dữ liệu rỗng
df.isnull().sum()
# Out:
# Ngày          0
# Lần cuối      0
# Mở            0
# Cao           0
# Thấp          0
# KL          978
# dtype: int64

# %%
#Xem độ biến thiên của từng thuộc tính.
df.plot(legend=True,subplots=True, figsize = (16, 9))
plt.show()

# %%
#Chuyển dataset về cột Close để tiến hành tạo model
df = df[['Lần cuối']]
df
# Out:
#       Lần cuối
# 0        886.2
# 1        899.5
# 2        908.3
# 3        904.6
# 4        910.4
# ...        ...
# 1553    1082.8
# 1554    1075.0
# 1555    1090.7
# 1556    1066.3
# 1557    1083.8
#
# [1558 rows x 1 columns]

# %%
#Chia dữ liệu theo các tỷ lệ 7:2:1
train_size = int(0.5 * len(df))
test_size = int(0.3 * len(df))
val_size = len(df) - train_size - test_size

train_data_df = df[:train_size]
test_data_df = df[train_size:train_size+test_size]
val_data_df = df[train_size+test_size:]

# %%
# Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df=scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
#Chia data đã Scaler
train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]

# %%
#Tạo hàm create dataset
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return np.array(dataX),np.array(dataY)

# %%
#Chia thành các tập X,y
time_step = 40
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)
X_val, y_val = create_dataset(val_data, time_step)

# %%
# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],1, X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1] , 1)
X_val = X_val.reshape(X_val.shape[0],1 ,X_val.shape[1] , 1)

# %% [markdown]
# Vì thuật toán Hybird Neural Netword là sự kết hợp của các loại mạng neural khác nhau nên ở đây em kết hợp 2 mạng neural đã học là:
# - Mạng neural hồi quy LSTM
# - Mạng neural tích nhập CNN
#
# Cụ thể thì các lớp CNN được sử dụng để trích xuất đặc trưng từ dữ liệu không gian hoặc hình ảnh. Sau đó, các đặc trưng này được biến đổi và truyền vào các lớp LSTM. Các lớp LSTM có khả năng xử lý dữ liệu chuỗi thời gian và tạo ra dự đoán hoặc phân loại dựa trên thông tin này.

# %%
#Tiến hành tạo model
import tensorflow as tf
import tensorflow.keras.backend as K 
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, Bidirectional, TimeDistributed
from tensorflow.keras.layers import MaxPooling1D, Flatten
from tensorflow.keras.regularizers import L1, L2
from tensorflow.keras.metrics import Accuracy
from tensorflow.keras.metrics import RootMeanSquaredError 
from tensorflow.keras.utils import plot_model

model = tf.keras.Sequential()

# CNN layers
model.add(TimeDistributed(Conv1D(256, kernel_size=3, activation='relu', input_shape=(None, 50 , 1))))
model.add(TimeDistributed(MaxPooling1D(2)))
model.add(TimeDistributed(Conv1D(128, kernel_size=3, activation='relu')))
model.add(TimeDistributed(MaxPooling1D(2)))
model.add(TimeDistributed(Conv1D(64, kernel_size=3, activation='relu')))
model.add(TimeDistributed(MaxPooling1D(2)))
model.add(TimeDistributed(Flatten()))

# LSTM layers
model.add(Bidirectional(LSTM(100, return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(100, return_sequences=False)))
model.add(Dropout(0.5))

#Final layers
model.add(Dense(1, activation='linear'))
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mse', 'mae'])

#fit model
history = model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=100,batch_size=50, verbose=1, shuffle =True)
# Out:
# Epoch 1/100
# 15/15 [==============================] - 11s 171ms/step - loss: 0.0529 - mse: 0.0529 - mae: 0.1854 - val_loss: 0.0671 - val_mse: 0.0671 - val_mae: 0.2387
# Epoch 2/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0096 - mse: 0.0096 - mae: 0.0728 - val_loss: 0.0344 - val_mse: 0.0344 - val_mae: 0.1593
# Epoch 3/100
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0073 - mse: 0.0073 - mae: 0.0627 - val_loss: 0.0281 - val_mse: 0.0281 - val_mae: 0.1412
# Epoch 4/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.0072 - mse: 0.0072 - mae: 0.0619 - val_loss: 0.0214 - val_mse: 0.0214 - val_mae: 0.1208
# Epoch 5/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0066 - mse: 0.0066 - mae: 0.0594 - val_loss: 0.0220 - val_mse: 0.0220 - val_mae: 0.1236
# Epoch 6/100
# 15/15 [==============================] - 1s 40ms/step - loss: 0.0063 - mse: 0.0063 - mae: 0.0581 - val_loss: 0.0251 - val_mse: 0.0251 - val_mae: 0.1347
# Epoch 7/100
# 15/15 [==============================] - 1s 42ms/step - loss: 0.0068 - mse: 0.0068 - mae: 0.0598 - val_loss: 0.0136 - val_mse: 0.0136 - val_mae: 0.0949
# Epoch 8/100
# 15/15 [==============================] - 1s 42ms/step - loss: 0.0057 - mse: 0.0057 - mae: 0.0550 - val_loss: 0.0311 - val_mse: 0.0311 - val_mae: 0.1559
# Epoch 9/100
# 15/15 [==============================] - 1s 34ms/step - loss: 0.0049 - mse: 0.0049 - mae: 0.0512 - val_loss: 0.0129 - val_mse: 0.0129 - val_mae: 0.0931
# Epoch 10/100
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0046 - mse: 0.0046 - mae: 0.0485 - val_loss: 0.0158 - val_mse: 0.0158 - val_mae: 0.1057
# Epoch 11/100
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0042 - mse: 0.0042 - mae: 0.0474 - val_loss: 0.0092 - val_mse: 0.0092 - val_mae: 0.0784
# Epoch 12/100
# 15/15 [==============================] - 1s 34ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0452 - val_loss: 0.0122 - val_mse: 0.0122 - val_mae: 0.0912
# Epoch 13/100
# 15/15 [==============================] - 1s 35ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0461 - val_loss: 0.0095 - val_mse: 0.0095 - val_mae: 0.0788
# Epoch 14/100
# 15/15 [==============================] - 1s 35ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0530 - val_loss: 0.0222 - val_mse: 0.0222 - val_mae: 0.1300
# Epoch 15/100
# 15/15 [==============================] - 1s 35ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0475 - val_loss: 0.0099 - val_mse: 0.0099 - val_mae: 0.0817
# Epoch 16/100
# 15/15 [==============================] - 1s 40ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0457 - val_loss: 0.0115 - val_mse: 0.0115 - val_mae: 0.0888
# Epoch 17/100
# 15/15 [==============================] - 1s 40ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0430 - val_loss: 0.0113 - val_mse: 0.0113 - val_mae: 0.0881
# Epoch 18/100
# 15/15 [==============================] - 1s 42ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0424 - val_loss: 0.0190 - val_mse: 0.0190 - val_mae: 0.1194
# Epoch 19/100
# 15/15 [==============================] - 1s 46ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0441 - val_loss: 0.0136 - val_mse: 0.0136 - val_mae: 0.0972
# Epoch 20/100
# 15/15 [==============================] - 1s 39ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0431 - val_loss: 0.0082 - val_mse: 0.0082 - val_mae: 0.0731
# Epoch 21/100
# 15/15 [==============================] - 1s 39ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0422 - val_loss: 0.0073 - val_mse: 0.0073 - val_mae: 0.0674
# Epoch 22/100
# 15/15 [==============================] - 1s 37ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0454 - val_loss: 0.0206 - val_mse: 0.0206 - val_mae: 0.1228
# Epoch 23/100
# 15/15 [==============================] - 1s 39ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0438 - val_loss: 0.0155 - val_mse: 0.0155 - val_mae: 0.1068
# Epoch 24/100
# 15/15 [==============================] - 1s 42ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0411 - val_loss: 0.0092 - val_mse: 0.0092 - val_mae: 0.0773
# Epoch 25/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0416 - val_loss: 0.0118 - val_mse: 0.0118 - val_mae: 0.0886
# Epoch 26/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0419 - val_loss: 0.0089 - val_mse: 0.0089 - val_mae: 0.0751
# Epoch 27/100
# 15/15 [==============================] - 1s 47ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0428 - val_loss: 0.0129 - val_mse: 0.0129 - val_mae: 0.0934
# Epoch 28/100
# 15/15 [==============================] - 1s 46ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0398 - val_loss: 0.0187 - val_mse: 0.0187 - val_mae: 0.1163
# Epoch 29/100
# 15/15 [==============================] - 1s 45ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0396 - val_loss: 0.0115 - val_mse: 0.0115 - val_mae: 0.0878
# Epoch 30/100
# 15/15 [==============================] - 1s 45ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0394 - val_loss: 0.0082 - val_mse: 0.0082 - val_mae: 0.0703
# Epoch 31/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0387 - val_loss: 0.0136 - val_mse: 0.0136 - val_mae: 0.0953
# Epoch 32/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0387 - val_loss: 0.0138 - val_mse: 0.0138 - val_mae: 0.0966
# Epoch 33/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0374 - val_loss: 0.0120 - val_mse: 0.0120 - val_mae: 0.0887
# Epoch 34/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0385 - val_loss: 0.0107 - val_mse: 0.0107 - val_mae: 0.0824
# Epoch 35/100
# 15/15 [==============================] - 1s 41ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0394 - val_loss: 0.0154 - val_mse: 0.0154 - val_mae: 0.1023
# Epoch 36/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0381 - val_loss: 0.0109 - val_mse: 0.0109 - val_mae: 0.0831
# Epoch 37/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0360 - val_loss: 0.0124 - val_mse: 0.0124 - val_mae: 0.0902
# Epoch 38/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0365 - val_loss: 0.0175 - val_mse: 0.0175 - val_mae: 0.1094
# Epoch 39/100
# 15/15 [==============================] - 1s 47ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0376 - val_loss: 0.0139 - val_mse: 0.0139 - val_mae: 0.0943
# Epoch 40/100
# 15/15 [==============================] - 1s 45ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0360 - val_loss: 0.0100 - val_mse: 0.0100 - val_mae: 0.0785
# Epoch 41/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0362 - val_loss: 0.0110 - val_mse: 0.0110 - val_mae: 0.0822
# Epoch 42/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0388 - val_loss: 0.0090 - val_mse: 0.0090 - val_mae: 0.0738
# Epoch 43/100
# 15/15 [==============================] - 1s 44ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0355 - val_loss: 0.0169 - val_mse: 0.0169 - val_mae: 0.1077
# Epoch 44/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0353 - val_loss: 0.0170 - val_mse: 0.0170 - val_mae: 0.1065
# Epoch 45/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0352 - val_loss: 0.0116 - val_mse: 0.0116 - val_mae: 0.0850
# Epoch 46/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0380 - val_loss: 0.0139 - val_mse: 0.0139 - val_mae: 0.0928
# Epoch 47/100
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0399 - val_loss: 0.0221 - val_mse: 0.0221 - val_mae: 0.1270
# Epoch 48/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0344 - val_loss: 0.0088 - val_mse: 0.0088 - val_mae: 0.0732
# Epoch 49/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0346 - val_loss: 0.0209 - val_mse: 0.0209 - val_mae: 0.1229
# Epoch 50/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0359 - val_loss: 0.0149 - val_mse: 0.0149 - val_mae: 0.0984
# Epoch 51/100
# 15/15 [==============================] - 1s 46ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0344 - val_loss: 0.0150 - val_mse: 0.0150 - val_mae: 0.1007
# Epoch 52/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0348 - val_loss: 0.0143 - val_mse: 0.0143 - val_mae: 0.0971
# Epoch 53/100
# 15/15 [==============================] - 1s 44ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0341 - val_loss: 0.0159 - val_mse: 0.0159 - val_mae: 0.1033
# Epoch 54/100
# 15/15 [==============================] - 1s 43ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0329 - val_loss: 0.0154 - val_mse: 0.0154 - val_mae: 0.1003
# Epoch 55/100
# 15/15 [==============================] - 1s 43ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0335 - val_loss: 0.0127 - val_mse: 0.0127 - val_mae: 0.0900
# Epoch 56/100
# 15/15 [==============================] - 1s 43ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0323 - val_loss: 0.0128 - val_mse: 0.0128 - val_mae: 0.0886
# Epoch 57/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0339 - val_loss: 0.0172 - val_mse: 0.0172 - val_mae: 0.1080
# Epoch 58/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0326 - val_loss: 0.0111 - val_mse: 0.0111 - val_mae: 0.0814
# Epoch 59/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0329 - val_loss: 0.0169 - val_mse: 0.0169 - val_mae: 0.1039
# Epoch 60/100
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0321 - val_loss: 0.0226 - val_mse: 0.0226 - val_mae: 0.1271
# Epoch 61/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0333 - val_loss: 0.0154 - val_mse: 0.0154 - val_mae: 0.1010
# Epoch 62/100
# 15/15 [==============================] - 1s 39ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0332 - val_loss: 0.0131 - val_mse: 0.0131 - val_mae: 0.0924
# Epoch 63/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0319 - val_loss: 0.0101 - val_mse: 0.0101 - val_mae: 0.0776
# Epoch 64/100
# 15/15 [==============================] - 1s 58ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0320 - val_loss: 0.0180 - val_mse: 0.0180 - val_mae: 0.1078
# Epoch 65/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0325 - val_loss: 0.0153 - val_mse: 0.0153 - val_mae: 0.1017
# Epoch 66/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0340 - val_loss: 0.0188 - val_mse: 0.0188 - val_mae: 0.1102
# Epoch 67/100
# 15/15 [==============================] - 1s 45ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0318 - val_loss: 0.0103 - val_mse: 0.0103 - val_mae: 0.0791
# Epoch 68/100
# 15/15 [==============================] - 1s 41ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0314 - val_loss: 0.0123 - val_mse: 0.0123 - val_mae: 0.0881
# Epoch 69/100
# 15/15 [==============================] - 1s 44ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0309 - val_loss: 0.0137 - val_mse: 0.0137 - val_mae: 0.0931
# Epoch 70/100
# 15/15 [==============================] - 1s 47ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0324 - val_loss: 0.0171 - val_mse: 0.0171 - val_mae: 0.1071
# Epoch 71/100
# 15/15 [==============================] - 1s 42ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0324 - val_loss: 0.0130 - val_mse: 0.0130 - val_mae: 0.0910
# Epoch 72/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0300 - val_loss: 0.0113 - val_mse: 0.0113 - val_mae: 0.0830
# Epoch 73/100
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0298 - val_loss: 0.0205 - val_mse: 0.0205 - val_mae: 0.1186
# Epoch 74/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0336 - val_loss: 0.0159 - val_mse: 0.0159 - val_mae: 0.1018
# Epoch 75/100
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0352 - val_loss: 0.0190 - val_mse: 0.0190 - val_mae: 0.1105
# Epoch 76/100
# 15/15 [==============================] - 1s 44ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0305 - val_loss: 0.0117 - val_mse: 0.0117 - val_mae: 0.0856
# Epoch 77/100
# 15/15 [==============================] - 1s 42ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0306 - val_loss: 0.0135 - val_mse: 0.0135 - val_mae: 0.0915
# Epoch 78/100
# 15/15 [==============================] - 1s 46ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0289 - val_loss: 0.0160 - val_mse: 0.0160 - val_mae: 0.1017
# Epoch 79/100
# 15/15 [==============================] - 1s 47ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0309 - val_loss: 0.0156 - val_mse: 0.0156 - val_mae: 0.1007
# Epoch 80/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0311 - val_loss: 0.0154 - val_mse: 0.0154 - val_mae: 0.0974
# Epoch 81/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0303 - val_loss: 0.0117 - val_mse: 0.0117 - val_mae: 0.0849
# Epoch 82/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0295 - val_loss: 0.0164 - val_mse: 0.0164 - val_mae: 0.1028
# Epoch 83/100
# 15/15 [==============================] - 1s 45ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0292 - val_loss: 0.0118 - val_mse: 0.0118 - val_mae: 0.0845
# Epoch 84/100
# 15/15 [==============================] - 1s 43ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0313 - val_loss: 0.0151 - val_mse: 0.0151 - val_mae: 0.0977
# Epoch 85/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0303 - val_loss: 0.0184 - val_mse: 0.0184 - val_mae: 0.1107
# Epoch 86/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0280 - val_loss: 0.0153 - val_mse: 0.0153 - val_mae: 0.0983
# Epoch 87/100
# 15/15 [==============================] - 1s 47ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0286 - val_loss: 0.0154 - val_mse: 0.0154 - val_mae: 0.0987
# Epoch 88/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0288 - val_loss: 0.0123 - val_mse: 0.0123 - val_mae: 0.0871
# Epoch 89/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0269 - val_loss: 0.0169 - val_mse: 0.0169 - val_mae: 0.1054
# Epoch 90/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0288 - val_loss: 0.0111 - val_mse: 0.0111 - val_mae: 0.0821
# Epoch 91/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0281 - val_loss: 0.0153 - val_mse: 0.0153 - val_mae: 0.0969
# Epoch 92/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0301 - val_loss: 0.0185 - val_mse: 0.0185 - val_mae: 0.1121
# Epoch 93/100
# 15/15 [==============================] - 1s 44ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0317 - val_loss: 0.0143 - val_mse: 0.0143 - val_mae: 0.0938
# Epoch 94/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0292 - val_loss: 0.0128 - val_mse: 0.0128 - val_mae: 0.0896
# Epoch 95/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0279 - val_loss: 0.0139 - val_mse: 0.0139 - val_mae: 0.0932
# Epoch 96/100
# 15/15 [==============================] - 1s 64ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0280 - val_loss: 0.0203 - val_mse: 0.0203 - val_mae: 0.1179
# Epoch 97/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0297 - val_loss: 0.0185 - val_mse: 0.0185 - val_mae: 0.1105
# Epoch 98/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0280 - val_loss: 0.0130 - val_mse: 0.0130 - val_mae: 0.0895
# Epoch 99/100
# 15/15 [==============================] - 1s 46ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0265 - val_loss: 0.0185 - val_mse: 0.0185 - val_mae: 0.1115
# Epoch 100/100
# 15/15 [==============================] - 1s 46ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0285 - val_loss: 0.0158 - val_mse: 0.0158 - val_mae: 0.1007

# %%
# Dự đoán

# Dự đoán train
y_pred_train=model.predict(X_train)
y_train=scaler.inverse_transform(y_train.reshape(-1,1))
y_pred_train=scaler.inverse_transform(y_pred_train.reshape(-1,1))
#Dự đoán Test
y_pred_test=model.predict(X_test)
y_test=scaler.inverse_transform(y_test.reshape(-1,1))
y_pred_test=scaler.inverse_transform(y_pred_test.reshape(-1,1))
#Dự đoán Validation
y_pred_val=model.predict(X_val)
y_val=scaler.inverse_transform(y_val.reshape(-1,1))
y_pred_val=scaler.inverse_transform(y_pred_val.reshape(-1,1))
# Out:
# 24/24 [==============================] - 9s 7ms/step
# 14/14 [==============================] - 0s 8ms/step
# 9/9 [==============================] - 0s 6ms/step

# %%
#Hàm visualize
def visualize(label ,pred, model_name):
  plt.figure(figsize=(12,8))
  plt.plot(label, label = 'Ground truth')
  plt.plot(pred, label='Predict')
  plt.title(model_name)
  plt.xlabel('Date')
  plt.ylabel('Closing Price')
  plt.legend()
  plt.show()

# %%
#Đánh giá 
def deviation(test, pred):
  rmse= np.sqrt(mean_squared_error(test,pred))
  print(f"RMSE: {rmse:.2f}")
  mape= mean_absolute_percentage_error(test,pred)
  print(f"MAPE: {mape*100:.2f}%")
  mae = mean_absolute_error(test, pred)
  print(f"MAE: {mae:.2f}")

# %%
# visualize(y_train,y_pred_train,'Biểu đồ dự đoán tập TRAIN')
visualize(y_test,y_pred_test,'Biểu đồ dự đoán tập TEST')
print('Đánh Giá tập TEST')
deviation(y_test, y_pred_test)
visualize(y_val,y_pred_val,'Biểu đồ dự đoán tập VALIDATION')
print('Đánh Giá tập VALIDATION')
deviation(y_val, y_pred_val)
# Out:
# Đánh Giá tập TEST
# RMSE: 91.04
# MAPE: 6.47%
# MAE: 72.87
# Đánh Giá tập VALIDATION
# RMSE: 48.61
# MAPE: 3.94%
# MAE: 38.83

# %%
# #Dự đoán 30 ngày tiếp theo
# pred_next = np.array([])
  
# y_val=y_val[-time_step:].reshape(1,-1).reshape(1,time_step)
  
# for i in range(30):
#     y_pred_next = model.predict(y_val.reshape(1,-1).reshape(1,1,time_step,1))
#     y_val = np.append(y_val,y_pred_next[0])[1:]
#     pred_next = np.append(pred_next,y_pred_next[0])
    
# next30days_predict_inverse = pd.DataFrame(scaler.inverse_transform(pred_next.reshape(-1,1)))

#Dự đoán 30 ngày tiếp theo
pred_next = np.array([])
  
y_val_to_next=scaler.fit_transform(np.array(y_val[-time_step:].reshape(1,-1).reshape(1,time_step)).reshape(-1,1))
  
for i in range(30):
    y_pred_next = model.predict(y_val_to_next.reshape(1,-1).reshape(1,1,time_step,1))
    y_val_to_next = np.append(y_val_to_next,y_pred_next[0])[1:]
    pred_next = np.append(pred_next,y_pred_next[0])
    
next30days_predict_inverse = pd.DataFrame(scaler.inverse_transform(pred_next.reshape(-1,1)))
# Out:
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 91ms/step

# %%
# Vẽ hình
plt.figure(figsize=(16,9))

train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(train_data_index,train_data_df)

test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index, test_data_df)

test_data_index = pd.RangeIndex(start=train_size+ 41, stop=train_size+test_size, step=1)
plt.plot(test_data_index,y_pred_test)

val_data_index = pd.RangeIndex(start=train_size + test_size, stop=train_size+test_size+val_size, step=1)
plt.plot(val_data_index, val_data_df)

val_data_index = pd.RangeIndex(start=train_size + test_size+ 41, stop=train_size+test_size+val_size, step=1)
plt.plot(val_data_index,y_pred_val)


prediect_data_index = pd.RangeIndex(start=len(df)-1, stop=len(df)+29, step=1)
plt.plot(prediect_data_index,next30days_predict_inverse)
plt.legend(['Train','Test','Predict','Validate','ValidatePred','Predict30days'])
plt.show()

# %%
from tensorflow.keras.utils import plot_model
print(model.summary())
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 1, 38, 256)       1024
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 1, 19, 256)       0
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 1, 17, 128)       98432
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 1, 8, 128)        0
#  tributed)
#
#  time_distributed_4 (TimeDis  (None, 1, 6, 64)         24640
#  tributed)
#
#  time_distributed_5 (TimeDis  (None, 1, 3, 64)         0
#  tributed)
#
#  time_distributed_6 (TimeDis  (None, 1, 192)           0
#  tributed)
#
#  bidirectional (Bidirectiona  (None, 1, 200)           234400
#  l)
#
#  dropout (Dropout)           (None, 1, 200)            0
#
#  bidirectional_1 (Bidirectio  (None, 200)              240800
#  nal)
#
#  dropout_1 (Dropout)         (None, 200)               0
#
#  dense (Dense)               (None, 1)                 201
#
# =================================================================
# Total params: 599,497
# Trainable params: 599,497
# Non-trainable params: 0
# _________________________________________________________________
# None
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.
