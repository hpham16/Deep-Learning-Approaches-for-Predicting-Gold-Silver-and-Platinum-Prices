# %% [markdown]
# # IS403.N22.HTCL
# ```python
# Team 16
# ```
# **SỬ DỤNG ĐỂ TÍNH TOÁN BỘ DỮ LIỆU GIÁ BẠC (19/05/2018 ĐẾN 19/05/2023)**
# - Tỷ lệ tính toán Train Data: 50% Dataset
# - Tỷ lệ tính toán Test Data: 30% Dataset
# - Tỷ lệ tính toán Validation Data: 20% Dataset

# %%
#Import các thư viện cần thiết
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from sklearn import preprocessing
from keras.layers import Conv1D,Flatten,MaxPooling1D,Bidirectional,LSTM,Dropout,TimeDistributed
from keras.layers import Dense,GlobalAveragePooling2D
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error,mean_absolute_error

# %%
#Đọc file dữ liệu và xem dữ liệu
df = pd.read_csv('../SilverData.csv',parse_dates=True)
df
# Out:
#            Ngày  Lần cuối      Mở     Cao    Thấp      KL
# 0     21/5/2018    16.520  16.430  16.535  16.280  63.89K
# 1     22/5/2018    16.575  16.530  16.700  16.465  73.53K
# 2     23/5/2018    16.405  16.555  16.600  16.330  89.46K
# 3     24/5/2018    16.687  16.475  16.715  16.420  91.02K
# 4     25/5/2018    16.546  16.690  16.740  16.500  72.71K
# ...         ...       ...     ...     ...     ...     ...
# 1275  15/5/2023    24.175  24.030  24.270  23.945   0.17K
# 1276  16/5/2023    23.783  24.115  24.115  23.710   0.18K
# 1277  17/5/2023    23.789  23.830  23.940  23.650   0.18K
# 1278  18/5/2023    23.523  23.840  23.840  23.380   0.35K
# 1279  19/5/2023    23.948  23.560  24.010  23.555   0.15K
#
# [1280 rows x 6 columns]

# %%
#Xem các dữ liệu cơ bản của cảc thuộc tính
df.describe()
# Out:
#           Lần cuối           Mở          Cao         Thấp
# count  1280.000000  1280.000000  1280.000000  1280.000000
# mean     20.414323    20.428459    20.685217    20.134988
# std       4.325552     4.335049     4.437082     4.203927
# min      11.772000    11.975000    12.330000    11.640000
# 25%      16.223000    16.252500    16.388750    16.080000
# 50%      20.350500    20.312500    20.762500    19.987500
# 75%      24.250750    24.251250    24.580000    23.872500
# max      29.418000    29.235000    30.350000    28.155000

# %%
#Kiểm tra dữ liệu rỗng
df.isnull().sum()
# Out:
# Ngày         0
# Lần cuối     0
# Mở           0
# Cao          0
# Thấp         0
# KL          28
# dtype: int64

# %%
#Xem độ biến thiên của từng thuộc tính.
df.plot(legend=True,subplots=True, figsize = (16, 9))
plt.show()

# %%
#Chuyển dataset về cột Close để tiến hành tạo model
df = df[['Lần cuối']]
df
# Out:
#       Lần cuối
# 0       16.520
# 1       16.575
# 2       16.405
# 3       16.687
# 4       16.546
# ...        ...
# 1275    24.175
# 1276    23.783
# 1277    23.789
# 1278    23.523
# 1279    23.948
#
# [1280 rows x 1 columns]

# %%
#Chia dữ liệu theo các tỷ lệ 7:2:1
train_size = int(0.5 * len(df))
test_size = int(0.3 * len(df))
val_size = len(df) - train_size - test_size

train_data_df = df[:train_size]
test_data_df = df[train_size:train_size+test_size]
val_data_df = df[train_size+test_size:]

# %%
# Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df=scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
#Chia data đã Scaler
train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]

# %%
#Tạo hàm create dataset
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return np.array(dataX),np.array(dataY)

# %%
#Chia thành các tập X,y
time_step = 40
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)
X_val, y_val = create_dataset(val_data, time_step)

# %%
# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],1, X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1] , 1)
X_val = X_val.reshape(X_val.shape[0],1 ,X_val.shape[1] , 1)

# %% [markdown]
# Vì thuật toán Hybird Neural Netword là sự kết hợp của các loại mạng neural khác nhau nên ở đây em kết hợp 2 mạng neural đã học là:
# - Mạng neural hồi quy LSTM
# - Mạng neural tích nhập CNN
#
# Cụ thể thì các lớp CNN được sử dụng để trích xuất đặc trưng từ dữ liệu không gian hoặc hình ảnh. Sau đó, các đặc trưng này được biến đổi và truyền vào các lớp LSTM. Các lớp LSTM có khả năng xử lý dữ liệu chuỗi thời gian và tạo ra dự đoán hoặc phân loại dựa trên thông tin này.

# %%
#Tiến hành tạo model
import tensorflow as tf
import tensorflow.keras.backend as K 
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, Bidirectional, TimeDistributed
from tensorflow.keras.layers import MaxPooling1D, Flatten
from tensorflow.keras.regularizers import L1, L2
from tensorflow.keras.metrics import Accuracy
from tensorflow.keras.metrics import RootMeanSquaredError 
from tensorflow.keras.utils import plot_model

model = tf.keras.Sequential()

# CNN layers
model.add(TimeDistributed(Conv1D(256, kernel_size=3, activation='relu', input_shape=(None, 50 , 1))))
model.add(TimeDistributed(MaxPooling1D(2)))
model.add(TimeDistributed(Conv1D(128, kernel_size=3, activation='relu')))
model.add(TimeDistributed(MaxPooling1D(2)))
model.add(TimeDistributed(Conv1D(64, kernel_size=3, activation='relu')))
model.add(TimeDistributed(MaxPooling1D(2)))
model.add(TimeDistributed(Flatten()))

# LSTM layers
model.add(Bidirectional(LSTM(100, return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(100, return_sequences=False)))
model.add(Dropout(0.5))

#Final layers
model.add(Dense(1, activation='linear'))
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mse', 'mae'])

#fit model
history = model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=100,batch_size=50, verbose=1, shuffle =True)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 15s 325ms/step - loss: 0.0729 - mse: 0.0729 - mae: 0.2033 - val_loss: 0.0067 - val_mse: 0.0067 - val_mae: 0.0675
# Epoch 2/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0175 - mse: 0.0175 - mae: 0.0873 - val_loss: 0.0065 - val_mse: 0.0065 - val_mae: 0.0646
# Epoch 3/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0122 - mse: 0.0122 - mae: 0.0793 - val_loss: 0.0093 - val_mse: 0.0093 - val_mae: 0.0788
# Epoch 4/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0093 - mse: 0.0093 - mae: 0.0655 - val_loss: 0.0102 - val_mse: 0.0102 - val_mae: 0.0832
# Epoch 5/100
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0091 - mse: 0.0091 - mae: 0.0623 - val_loss: 0.0054 - val_mse: 0.0054 - val_mae: 0.0604
# Epoch 6/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0084 - mse: 0.0084 - mae: 0.0584 - val_loss: 0.0085 - val_mse: 0.0085 - val_mae: 0.0759
# Epoch 7/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0088 - mse: 0.0088 - mae: 0.0607 - val_loss: 0.0133 - val_mse: 0.0133 - val_mae: 0.0996
# Epoch 8/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0065 - mse: 0.0065 - mae: 0.0522 - val_loss: 0.0061 - val_mse: 0.0061 - val_mae: 0.0643
# Epoch 9/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0064 - mse: 0.0064 - mae: 0.0519 - val_loss: 0.0058 - val_mse: 0.0058 - val_mae: 0.0627
# Epoch 10/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0069 - mse: 0.0069 - mae: 0.0533 - val_loss: 0.0082 - val_mse: 0.0082 - val_mae: 0.0767
# Epoch 11/100
# 12/12 [==============================] - 0s 28ms/step - loss: 0.0055 - mse: 0.0055 - mae: 0.0486 - val_loss: 0.0281 - val_mse: 0.0281 - val_mae: 0.1547
# Epoch 12/100
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0066 - mse: 0.0066 - mae: 0.0553 - val_loss: 0.0141 - val_mse: 0.0141 - val_mae: 0.1040
# Epoch 13/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0060 - mse: 0.0060 - mae: 0.0493 - val_loss: 0.0170 - val_mse: 0.0170 - val_mae: 0.1164
# Epoch 14/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0452 - val_loss: 0.0039 - val_mse: 0.0039 - val_mae: 0.0521
# Epoch 15/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0052 - mse: 0.0052 - mae: 0.0462 - val_loss: 0.0040 - val_mse: 0.0040 - val_mae: 0.0518
# Epoch 16/100
# 12/12 [==============================] - 0s 28ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0420 - val_loss: 0.0062 - val_mse: 0.0062 - val_mae: 0.0676
# Epoch 17/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0045 - mse: 0.0045 - mae: 0.0441 - val_loss: 0.0091 - val_mse: 0.0091 - val_mae: 0.0826
# Epoch 18/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0055 - mse: 0.0055 - mae: 0.0481 - val_loss: 0.0037 - val_mse: 0.0037 - val_mae: 0.0503
# Epoch 19/100
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0457 - val_loss: 0.0038 - val_mse: 0.0038 - val_mae: 0.0508
# Epoch 20/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0045 - mse: 0.0045 - mae: 0.0451 - val_loss: 0.0046 - val_mse: 0.0046 - val_mae: 0.0524
# Epoch 21/100
# 12/12 [==============================] - 0s 28ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0425 - val_loss: 0.0040 - val_mse: 0.0040 - val_mae: 0.0496
# Epoch 22/100
# 12/12 [==============================] - 0s 28ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0396 - val_loss: 0.0037 - val_mse: 0.0037 - val_mae: 0.0507
# Epoch 23/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0415 - val_loss: 0.0041 - val_mse: 0.0041 - val_mae: 0.0543
# Epoch 24/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0428 - val_loss: 0.0050 - val_mse: 0.0050 - val_mae: 0.0600
# Epoch 25/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0385 - val_loss: 0.0040 - val_mse: 0.0040 - val_mae: 0.0527
# Epoch 26/100
# 12/12 [==============================] - 0s 27ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0378 - val_loss: 0.0039 - val_mse: 0.0039 - val_mae: 0.0518
# Epoch 27/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0390 - val_loss: 0.0042 - val_mse: 0.0042 - val_mae: 0.0542
# Epoch 28/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0368 - val_loss: 0.0042 - val_mse: 0.0042 - val_mae: 0.0542
# Epoch 29/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0371 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0606
# Epoch 30/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0379 - val_loss: 0.0038 - val_mse: 0.0038 - val_mae: 0.0517
# Epoch 31/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0042 - mse: 0.0042 - mae: 0.0418 - val_loss: 0.0042 - val_mse: 0.0042 - val_mae: 0.0500
# Epoch 32/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0387 - val_loss: 0.0044 - val_mse: 0.0044 - val_mae: 0.0509
# Epoch 33/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0381 - val_loss: 0.0037 - val_mse: 0.0037 - val_mae: 0.0505
# Epoch 34/100
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0368 - val_loss: 0.0037 - val_mse: 0.0037 - val_mae: 0.0480
# Epoch 35/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0370 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0487
# Epoch 36/100
# 12/12 [==============================] - 0s 28ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0355 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0481
# Epoch 37/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0370 - val_loss: 0.0038 - val_mse: 0.0038 - val_mae: 0.0476
# Epoch 38/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0361 - val_loss: 0.0037 - val_mse: 0.0037 - val_mae: 0.0486
# Epoch 39/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0381 - val_loss: 0.0082 - val_mse: 0.0082 - val_mae: 0.0779
# Epoch 40/100
# 12/12 [==============================] - 0s 28ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0373 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0485
# Epoch 41/100
# 12/12 [==============================] - 0s 28ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0367 - val_loss: 0.0038 - val_mse: 0.0038 - val_mae: 0.0499
# Epoch 42/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0359 - val_loss: 0.0053 - val_mse: 0.0053 - val_mae: 0.0616
# Epoch 43/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0364 - val_loss: 0.0040 - val_mse: 0.0040 - val_mae: 0.0517
# Epoch 44/100
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0326 - val_loss: 0.0038 - val_mse: 0.0038 - val_mae: 0.0485
# Epoch 45/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0366 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0474
# Epoch 46/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0339 - val_loss: 0.0042 - val_mse: 0.0042 - val_mae: 0.0532
# Epoch 47/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0356 - val_loss: 0.0037 - val_mse: 0.0037 - val_mae: 0.0485
# Epoch 48/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0341 - val_loss: 0.0041 - val_mse: 0.0041 - val_mae: 0.0524
# Epoch 49/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0322 - val_loss: 0.0039 - val_mse: 0.0039 - val_mae: 0.0492
# Epoch 50/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0364 - val_loss: 0.0038 - val_mse: 0.0038 - val_mae: 0.0489
# Epoch 51/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0351 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0480
# Epoch 52/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0338 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0479
# Epoch 53/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0323 - val_loss: 0.0062 - val_mse: 0.0062 - val_mae: 0.0658
# Epoch 54/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0337 - val_loss: 0.0044 - val_mse: 0.0044 - val_mae: 0.0523
# Epoch 55/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0320 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0565
# Epoch 56/100
# 12/12 [==============================] - 0s 28ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0324 - val_loss: 0.0066 - val_mse: 0.0066 - val_mae: 0.0673
# Epoch 57/100
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0341 - val_loss: 0.0045 - val_mse: 0.0045 - val_mae: 0.0543
# Epoch 58/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0338 - val_loss: 0.0047 - val_mse: 0.0047 - val_mae: 0.0558
# Epoch 59/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0328 - val_loss: 0.0040 - val_mse: 0.0040 - val_mae: 0.0508
# Epoch 60/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0332 - val_loss: 0.0045 - val_mse: 0.0045 - val_mae: 0.0542
# Epoch 61/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0352 - val_loss: 0.0038 - val_mse: 0.0038 - val_mae: 0.0496
# Epoch 62/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0330 - val_loss: 0.0054 - val_mse: 0.0054 - val_mae: 0.0599
# Epoch 63/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0327 - val_loss: 0.0056 - val_mse: 0.0056 - val_mae: 0.0609
# Epoch 64/100
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0326 - val_loss: 0.0043 - val_mse: 0.0043 - val_mae: 0.0528
# Epoch 65/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0334 - val_loss: 0.0043 - val_mse: 0.0043 - val_mae: 0.0525
# Epoch 66/100
# 12/12 [==============================] - 0s 28ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0331 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0582
# Epoch 67/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0337 - val_loss: 0.0050 - val_mse: 0.0050 - val_mae: 0.0572
# Epoch 68/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0312 - val_loss: 0.0059 - val_mse: 0.0059 - val_mae: 0.0621
# Epoch 69/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0313 - val_loss: 0.0062 - val_mse: 0.0062 - val_mae: 0.0643
# Epoch 70/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0317 - val_loss: 0.0046 - val_mse: 0.0046 - val_mae: 0.0545
# Epoch 71/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0325 - val_loss: 0.0048 - val_mse: 0.0048 - val_mae: 0.0556
# Epoch 72/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0318 - val_loss: 0.0044 - val_mse: 0.0044 - val_mae: 0.0535
# Epoch 73/100
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0302 - val_loss: 0.0045 - val_mse: 0.0045 - val_mae: 0.0538
# Epoch 74/100
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0341 - val_loss: 0.0048 - val_mse: 0.0048 - val_mae: 0.0557
# Epoch 75/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0319 - val_loss: 0.0050 - val_mse: 0.0050 - val_mae: 0.0577
# Epoch 76/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0319 - val_loss: 0.0054 - val_mse: 0.0054 - val_mae: 0.0592
# Epoch 77/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0313 - val_loss: 0.0044 - val_mse: 0.0044 - val_mae: 0.0530
# Epoch 78/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0296 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0566
# Epoch 79/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0319 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0564
# Epoch 80/100
# 12/12 [==============================] - 0s 28ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0306 - val_loss: 0.0047 - val_mse: 0.0047 - val_mae: 0.0553
# Epoch 81/100
# 12/12 [==============================] - 0s 28ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0308 - val_loss: 0.0046 - val_mse: 0.0046 - val_mae: 0.0548
# Epoch 82/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0304 - val_loss: 0.0050 - val_mse: 0.0050 - val_mae: 0.0578
# Epoch 83/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0300 - val_loss: 0.0053 - val_mse: 0.0053 - val_mae: 0.0589
# Epoch 84/100
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0286 - val_loss: 0.0047 - val_mse: 0.0047 - val_mae: 0.0553
# Epoch 85/100
# 12/12 [==============================] - 0s 21ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0295 - val_loss: 0.0062 - val_mse: 0.0062 - val_mae: 0.0643
# Epoch 86/100
# 12/12 [==============================] - 0s 21ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0299 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0560
# Epoch 87/100
# 12/12 [==============================] - 0s 21ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0303 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0588
# Epoch 88/100
# 12/12 [==============================] - 0s 21ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0301 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0574
# Epoch 89/100
# 12/12 [==============================] - 0s 21ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0312 - val_loss: 0.0060 - val_mse: 0.0060 - val_mae: 0.0627
# Epoch 90/100
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0335 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0578
# Epoch 91/100
# 12/12 [==============================] - 0s 20ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0284 - val_loss: 0.0053 - val_mse: 0.0053 - val_mae: 0.0592
# Epoch 92/100
# 12/12 [==============================] - 0s 21ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0297 - val_loss: 0.0046 - val_mse: 0.0046 - val_mae: 0.0554
# Epoch 93/100
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0298 - val_loss: 0.0059 - val_mse: 0.0059 - val_mae: 0.0621
# Epoch 94/100
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0269 - val_loss: 0.0050 - val_mse: 0.0050 - val_mae: 0.0571
# Epoch 95/100
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0279 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0584
# Epoch 96/100
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0299 - val_loss: 0.0060 - val_mse: 0.0060 - val_mae: 0.0623
# Epoch 97/100
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0276 - val_loss: 0.0056 - val_mse: 0.0056 - val_mae: 0.0612
# Epoch 98/100
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0278 - val_loss: 0.0055 - val_mse: 0.0055 - val_mae: 0.0601
# Epoch 99/100
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0289 - val_loss: 0.0050 - val_mse: 0.0050 - val_mae: 0.0576
# Epoch 100/100
# 12/12 [==============================] - 0s 20ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0294 - val_loss: 0.0048 - val_mse: 0.0048 - val_mae: 0.0564

# %%
# Dự đoán

# Dự đoán train
y_pred_train=model.predict(X_train)
y_train=scaler.inverse_transform(y_train.reshape(-1,1))
y_pred_train=scaler.inverse_transform(y_pred_train.reshape(-1,1))
#Dự đoán Test
y_pred_test=model.predict(X_test)
y_test=scaler.inverse_transform(y_test.reshape(-1,1))
y_pred_test=scaler.inverse_transform(y_pred_test.reshape(-1,1))
#Dự đoán Validation
y_pred_val=model.predict(X_val)
y_val=scaler.inverse_transform(y_val.reshape(-1,1))
y_pred_val=scaler.inverse_transform(y_pred_val.reshape(-1,1))
# Out:
# 19/19 [==============================] - 1s 4ms/step
# 11/11 [==============================] - 0s 4ms/step
# 7/7 [==============================] - 0s 4ms/step

# %%
#Hàm visualize
def visualize(label ,pred, model_name):
  plt.figure(figsize=(12,8))
  plt.plot(label, label = 'Ground truth')
  plt.plot(pred, label='Predict')
  plt.title(model_name)
  plt.xlabel('Date')
  plt.ylabel('Closing Price')
  plt.legend()
  plt.show()

# %%
#Đánh giá 
def deviation(test, pred):
  rmse= np.sqrt(mean_squared_error(test,pred))
  print(f"RMSE: {rmse:.2f}")
  mape= mean_absolute_percentage_error(test,pred)
  print(f"MAPE: {mape*100:.2f}%")
  mae = mean_absolute_error(test, pred)
  print(f"MAE: {mae:.2f}")

# %%
# visualize(y_train,y_pred_train,'Biểu đồ dự đoán tập TRAIN')
visualize(y_test,y_pred_test,'Biểu đồ dự đoán tập TEST')
print('Đánh Giá tập TEST')
deviation(y_test, y_pred_test)
visualize(y_val,y_pred_val,'Biểu đồ dự đoán tập VALIDATION')
print('Đánh Giá tập VALIDATION')
deviation(y_val, y_pred_val)
# Out:
# Đánh Giá tập TEST
# RMSE: 1.22
# MAPE: 4.04%
# MAE: 1.00
# Đánh Giá tập VALIDATION
# RMSE: 1.51
# MAPE: 5.86%
# MAE: 1.22

# %%
# #Dự đoán 30 ngày tiếp theo
# pred_next = np.array([])
  
# y_val=y_val[-time_step:].reshape(1,-1).reshape(1,time_step)
  
# for i in range(30):
#     y_pred_next = model.predict(y_val.reshape(1,-1).reshape(1,1,time_step,1))
#     y_val = np.append(y_val,y_pred_next[0])[1:]
#     pred_next = np.append(pred_next,y_pred_next[0])
    
# next30days_predict_inverse = pd.DataFrame(scaler.inverse_transform(pred_next.reshape(-1,1)))

#Dự đoán 30 ngày tiếp theo
pred_next = np.array([])
  
y_val_to_next=scaler.fit_transform(np.array(y_val[-time_step:].reshape(1,-1).reshape(1,time_step)).reshape(-1,1))
  
for i in range(30):
    y_pred_next = model.predict(y_val_to_next.reshape(1,-1).reshape(1,1,time_step,1))
    y_val_to_next = np.append(y_val_to_next,y_pred_next[0])[1:]
    pred_next = np.append(pred_next,y_pred_next[0])
    
next30days_predict_inverse = pd.DataFrame(scaler.inverse_transform(pred_next.reshape(-1,1)))
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step

# %%
# Vẽ hình
plt.figure(figsize=(16,9))

train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(train_data_index,train_data_df)

test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index, test_data_df)

test_data_index = pd.RangeIndex(start=train_size+ 41, stop=train_size+test_size, step=1)
plt.plot(test_data_index,y_pred_test)

val_data_index = pd.RangeIndex(start=train_size + test_size, stop=train_size+test_size+val_size, step=1)
plt.plot(val_data_index, val_data_df)

val_data_index = pd.RangeIndex(start=train_size + test_size+ 41, stop=train_size+test_size+val_size, step=1)
plt.plot(val_data_index,y_pred_val)


prediect_data_index = pd.RangeIndex(start=len(df)-1, stop=len(df)+29, step=1)
plt.plot(prediect_data_index,next30days_predict_inverse)
plt.legend(['Train','Test','Predict','Validate','ValidatePred','Predict30days'])
plt.show()

# %%
from tensorflow.keras.utils import plot_model
print(model.summary())
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_7 (TimeDis  (None, 1, 38, 256)       1024
#  tributed)
#
#  time_distributed_8 (TimeDis  (None, 1, 19, 256)       0
#  tributed)
#
#  time_distributed_9 (TimeDis  (None, 1, 17, 128)       98432
#  tributed)
#
#  time_distributed_10 (TimeDi  (None, 1, 8, 128)        0
#  stributed)
#
#  time_distributed_11 (TimeDi  (None, 1, 6, 64)         24640
#  stributed)
#
#  time_distributed_12 (TimeDi  (None, 1, 3, 64)         0
#  stributed)
#
#  time_distributed_13 (TimeDi  (None, 1, 192)           0
#  stributed)
#
#  bidirectional_2 (Bidirectio  (None, 1, 200)           234400
#  nal)
#
#  dropout_2 (Dropout)         (None, 1, 200)            0
#
#  bidirectional_3 (Bidirectio  (None, 200)              240800
#  nal)
#
#  dropout_3 (Dropout)         (None, 200)               0
#
#  dense_1 (Dense)             (None, 1)                 201
#
# =================================================================
# Total params: 599,497
# Trainable params: 599,497
# Non-trainable params: 0
# _________________________________________________________________
# None
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.
