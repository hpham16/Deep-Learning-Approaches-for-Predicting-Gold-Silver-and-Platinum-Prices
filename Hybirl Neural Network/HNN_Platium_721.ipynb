# %% [markdown]
# # IS403.N22.HTCL
# ```python
# Team 16
# ```
# **SỬ DỤNG ĐỂ TÍNH TOÁN BỘ DỮ LIỆU GIÁ BẠCH KIM (19/05/2018 ĐẾN 19/05/2023)**
# - Tỷ lệ tính toán Train Data: 70% Dataset
# - Tỷ lệ tính toán Test Data: 20% Dataset
# - Tỷ lệ tính toán Validation Data: 10% Dataset

# %%
#Import các thư viện cần thiết
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from sklearn import preprocessing
from keras.layers import Conv1D,Flatten,MaxPooling1D,Bidirectional,LSTM,Dropout,TimeDistributed
from keras.layers import Dense,GlobalAveragePooling2D
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error,mean_absolute_error

# %%
#Đọc file dữ liệu và xem dữ liệu
df = pd.read_csv('../PlatiumData.csv',parse_dates=True)
df
# Out:
#            Ngày  Lần cuối      Mở     Cao    Thấp   KL
# 0     20/5/2018     886.2   886.8   889.0   885.5  NaN
# 1     21/5/2018     899.5   886.2   902.7   877.8  NaN
# 2     22/5/2018     908.3   899.5   912.0   896.3  NaN
# 3     23/5/2018     904.6   908.3   910.4   898.5  NaN
# 4     24/5/2018     910.4   904.6   914.7   903.5  NaN
# ...         ...       ...     ...     ...     ...  ...
# 1553  15/5/2023    1082.8  1057.6  1079.1  1057.5  NaN
# 1554  16/5/2023    1075.0  1070.5  1078.7  1061.8  NaN
# 1555  17/5/2023    1090.7  1067.7  1086.1  1067.4  NaN
# 1556  18/5/2023    1066.3  1079.2  1080.8  1055.0  NaN
# 1557  19/5/2023    1083.8  1059.6  1084.2  1055.0  NaN
#
# [1558 rows x 6 columns]

# %%
#Xem các dữ liệu cơ bản của cảc thuộc tính
df.describe()
# Out:
#           Lần cuối           Mở          Cao         Thấp
# count  1558.000000  1558.000000  1558.000000  1558.000000
# mean    944.065918   943.859884   955.499743   932.064955
# std     116.994315   116.800419   119.007199   115.160228
# min     595.200000   596.050000   615.400000   562.000000
# 25%     852.987500   852.887500   862.150000   844.275000
# 50%     930.875000   931.225000   941.900000   920.700000
# 75%    1018.200000  1017.575000  1029.475000  1003.175000
# max    1318.750000  1292.800000  1351.200000  1283.150000

# %%
#Kiểm tra dữ liệu rỗng
df.isnull().sum()
# Out:
# Ngày          0
# Lần cuối      0
# Mở            0
# Cao           0
# Thấp          0
# KL          978
# dtype: int64

# %%
#Xem độ biến thiên của từng thuộc tính.
df.plot(legend=True,subplots=True, figsize = (16, 9))
plt.show()

# %%
#Chuyển dataset về cột Close để tiến hành tạo model
df = df[['Lần cuối']]
df
# Out:
#       Lần cuối
# 0        886.2
# 1        899.5
# 2        908.3
# 3        904.6
# 4        910.4
# ...        ...
# 1553    1082.8
# 1554    1075.0
# 1555    1090.7
# 1556    1066.3
# 1557    1083.8
#
# [1558 rows x 1 columns]

# %%
#Chia dữ liệu theo các tỷ lệ 7:2:1
train_size = int(0.7 * len(df))
test_size = int(0.2 * len(df))
val_size = len(df) - train_size - test_size

train_data_df = df[:train_size]
test_data_df = df[train_size:train_size+test_size]
val_data_df = df[train_size+test_size:]

# %%
# Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df=scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
#Chia data đã Scaler
train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]

# %%
#Tạo hàm create dataset
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return np.array(dataX),np.array(dataY)

# %%
#Chia thành các tập X,y
time_step = 40
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)
X_val, y_val = create_dataset(val_data, time_step)

# %%
# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],1, X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1] , 1)
X_val = X_val.reshape(X_val.shape[0],1 ,X_val.shape[1] , 1)

# %% [markdown]
# Vì thuật toán Hybird Neural Netword là sự kết hợp của các loại mạng neural khác nhau nên ở đây em kết hợp 2 mạng neural đã học là:
# - Mạng neural hồi quy LSTM
# - Mạng neural tích nhập CNN
#
# Cụ thể thì các lớp CNN được sử dụng để trích xuất đặc trưng từ dữ liệu không gian hoặc hình ảnh. Sau đó, các đặc trưng này được biến đổi và truyền vào các lớp LSTM. Các lớp LSTM có khả năng xử lý dữ liệu chuỗi thời gian và tạo ra dự đoán hoặc phân loại dựa trên thông tin này.

# %%
#Tiến hành tạo model
import tensorflow as tf
import tensorflow.keras.backend as K 
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, Bidirectional, TimeDistributed
from tensorflow.keras.layers import MaxPooling1D, Flatten
from tensorflow.keras.regularizers import L1, L2
from tensorflow.keras.metrics import Accuracy
from tensorflow.keras.metrics import RootMeanSquaredError 
from tensorflow.keras.utils import plot_model

model = tf.keras.Sequential()

# CNN layers
model.add(TimeDistributed(Conv1D(256, kernel_size=3, activation='relu', input_shape=(None, 50 , 1))))
model.add(TimeDistributed(MaxPooling1D(2)))
model.add(TimeDistributed(Conv1D(128, kernel_size=3, activation='relu')))
model.add(TimeDistributed(MaxPooling1D(2)))
model.add(TimeDistributed(Conv1D(64, kernel_size=3, activation='relu')))
model.add(TimeDistributed(MaxPooling1D(2)))
model.add(TimeDistributed(Flatten()))

# LSTM layers
model.add(Bidirectional(LSTM(100, return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(100, return_sequences=False)))
model.add(Dropout(0.5))

#Final layers
model.add(Dense(1, activation='linear'))
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mse', 'mae'])

#fit model
history = model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=100,batch_size=50, verbose=1, shuffle =True)
# Out:
# Epoch 1/100
# 21/21 [==============================] - 21s 592ms/step - loss: 0.0771 - mse: 0.0771 - mae: 0.2137 - val_loss: 0.0062 - val_mse: 0.0062 - val_mae: 0.0634
# Epoch 2/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0150 - mse: 0.0150 - mae: 0.0928 - val_loss: 0.0082 - val_mse: 0.0082 - val_mae: 0.0743
# Epoch 3/100
# 21/21 [==============================] - 1s 38ms/step - loss: 0.0121 - mse: 0.0121 - mae: 0.0815 - val_loss: 0.0061 - val_mse: 0.0061 - val_mae: 0.0651
# Epoch 4/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0101 - mse: 0.0101 - mae: 0.0742 - val_loss: 0.0064 - val_mse: 0.0064 - val_mae: 0.0663
# Epoch 5/100
# 21/21 [==============================] - 1s 37ms/step - loss: 0.0093 - mse: 0.0093 - mae: 0.0717 - val_loss: 0.0069 - val_mse: 0.0069 - val_mae: 0.0669
# Epoch 6/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0098 - mse: 0.0098 - mae: 0.0725 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0608
# Epoch 7/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0075 - mse: 0.0075 - mae: 0.0643 - val_loss: 0.0048 - val_mse: 0.0048 - val_mae: 0.0578
# Epoch 8/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0075 - mse: 0.0075 - mae: 0.0628 - val_loss: 0.0047 - val_mse: 0.0047 - val_mae: 0.0560
# Epoch 9/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0067 - mse: 0.0067 - mae: 0.0602 - val_loss: 0.0037 - val_mse: 0.0037 - val_mae: 0.0507
# Epoch 10/100
# 21/21 [==============================] - 1s 36ms/step - loss: 0.0059 - mse: 0.0059 - mae: 0.0563 - val_loss: 0.0044 - val_mse: 0.0044 - val_mae: 0.0549
# Epoch 11/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0060 - mse: 0.0060 - mae: 0.0571 - val_loss: 0.0037 - val_mse: 0.0037 - val_mae: 0.0495
# Epoch 12/100
# 21/21 [==============================] - 1s 46ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0542 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0486
# Epoch 13/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0051 - mse: 0.0051 - mae: 0.0535 - val_loss: 0.0041 - val_mse: 0.0041 - val_mae: 0.0526
# Epoch 14/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0058 - mse: 0.0058 - mae: 0.0573 - val_loss: 0.0043 - val_mse: 0.0043 - val_mae: 0.0532
# Epoch 15/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0051 - mse: 0.0051 - mae: 0.0532 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0453
# Epoch 16/100
# 21/21 [==============================] - 1s 44ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0519 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0464
# Epoch 17/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0505 - val_loss: 0.0055 - val_mse: 0.0055 - val_mae: 0.0616
# Epoch 18/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0549 - val_loss: 0.0035 - val_mse: 0.0035 - val_mae: 0.0481
# Epoch 19/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0046 - mse: 0.0046 - mae: 0.0505 - val_loss: 0.0040 - val_mse: 0.0040 - val_mae: 0.0493
# Epoch 20/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0045 - mse: 0.0045 - mae: 0.0496 - val_loss: 0.0031 - val_mse: 0.0031 - val_mae: 0.0441
# Epoch 21/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0504 - val_loss: 0.0032 - val_mse: 0.0032 - val_mae: 0.0447
# Epoch 22/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0042 - mse: 0.0042 - mae: 0.0477 - val_loss: 0.0033 - val_mse: 0.0033 - val_mae: 0.0442
# Epoch 23/100
# 21/21 [==============================] - 1s 37ms/step - loss: 0.0045 - mse: 0.0045 - mae: 0.0489 - val_loss: 0.0031 - val_mse: 0.0031 - val_mae: 0.0440
# Epoch 24/100
# 21/21 [==============================] - 1s 38ms/step - loss: 0.0042 - mse: 0.0042 - mae: 0.0482 - val_loss: 0.0032 - val_mse: 0.0032 - val_mae: 0.0438
# Epoch 25/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0478 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0585
# Epoch 26/100
# 21/21 [==============================] - 1s 37ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0468 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0425
# Epoch 27/100
# 21/21 [==============================] - 1s 38ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0456 - val_loss: 0.0029 - val_mse: 0.0029 - val_mae: 0.0410
# Epoch 28/100
# 21/21 [==============================] - 1s 35ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0451 - val_loss: 0.0041 - val_mse: 0.0041 - val_mae: 0.0516
# Epoch 29/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0456 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0417
# Epoch 30/100
# 21/21 [==============================] - 1s 38ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0465 - val_loss: 0.0033 - val_mse: 0.0033 - val_mae: 0.0454
# Epoch 31/100
# 21/21 [==============================] - 1s 45ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0441 - val_loss: 0.0028 - val_mse: 0.0028 - val_mae: 0.0398
# Epoch 32/100
# 21/21 [==============================] - 1s 48ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0465 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0430
# Epoch 33/100
# 21/21 [==============================] - 1s 35ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0446 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0421
# Epoch 34/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0436 - val_loss: 0.0028 - val_mse: 0.0028 - val_mae: 0.0398
# Epoch 35/100
# 21/21 [==============================] - 1s 48ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0446 - val_loss: 0.0029 - val_mse: 0.0029 - val_mae: 0.0420
# Epoch 36/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0433 - val_loss: 0.0031 - val_mse: 0.0031 - val_mae: 0.0432
# Epoch 37/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0434 - val_loss: 0.0032 - val_mse: 0.0032 - val_mae: 0.0433
# Epoch 38/100
# 21/21 [==============================] - 1s 35ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0430 - val_loss: 0.0028 - val_mse: 0.0028 - val_mae: 0.0411
# Epoch 39/100
# 21/21 [==============================] - 1s 38ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0416 - val_loss: 0.0028 - val_mse: 0.0028 - val_mae: 0.0415
# Epoch 40/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0401 - val_loss: 0.0028 - val_mse: 0.0028 - val_mae: 0.0406
# Epoch 41/100
# 21/21 [==============================] - 1s 44ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0411 - val_loss: 0.0029 - val_mse: 0.0029 - val_mae: 0.0419
# Epoch 42/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0426 - val_loss: 0.0038 - val_mse: 0.0038 - val_mae: 0.0488
# Epoch 43/100
# 21/21 [==============================] - 1s 45ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0439 - val_loss: 0.0035 - val_mse: 0.0035 - val_mae: 0.0469
# Epoch 44/100
# 21/21 [==============================] - 1s 46ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0435 - val_loss: 0.0032 - val_mse: 0.0032 - val_mae: 0.0446
# Epoch 45/100
# 21/21 [==============================] - 1s 35ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0421 - val_loss: 0.0032 - val_mse: 0.0032 - val_mae: 0.0439
# Epoch 46/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0399 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0418
# Epoch 47/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0409 - val_loss: 0.0031 - val_mse: 0.0031 - val_mae: 0.0448
# Epoch 48/100
# 21/21 [==============================] - 1s 44ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0427 - val_loss: 0.0033 - val_mse: 0.0033 - val_mae: 0.0455
# Epoch 49/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0416 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0460
# Epoch 50/100
# 21/21 [==============================] - 1s 44ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0451 - val_loss: 0.0039 - val_mse: 0.0039 - val_mae: 0.0504
# Epoch 51/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0411 - val_loss: 0.0032 - val_mse: 0.0032 - val_mae: 0.0440
# Epoch 52/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0431 - val_loss: 0.0027 - val_mse: 0.0027 - val_mae: 0.0404
# Epoch 53/100
# 21/21 [==============================] - 1s 47ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0387 - val_loss: 0.0032 - val_mse: 0.0032 - val_mae: 0.0441
# Epoch 54/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0400 - val_loss: 0.0029 - val_mse: 0.0029 - val_mae: 0.0418
# Epoch 55/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0392 - val_loss: 0.0028 - val_mse: 0.0028 - val_mae: 0.0403
# Epoch 56/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0390 - val_loss: 0.0029 - val_mse: 0.0029 - val_mae: 0.0417
# Epoch 57/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0393 - val_loss: 0.0031 - val_mse: 0.0031 - val_mae: 0.0420
# Epoch 58/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0395 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0450
# Epoch 59/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0408 - val_loss: 0.0028 - val_mse: 0.0028 - val_mae: 0.0401
# Epoch 60/100
# 21/21 [==============================] - 1s 45ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0389 - val_loss: 0.0029 - val_mse: 0.0029 - val_mae: 0.0409
# Epoch 61/100
# 21/21 [==============================] - 1s 48ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0376 - val_loss: 0.0033 - val_mse: 0.0033 - val_mae: 0.0453
# Epoch 62/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0396 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0463
# Epoch 63/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0390 - val_loss: 0.0026 - val_mse: 0.0026 - val_mae: 0.0394
# Epoch 64/100
# 21/21 [==============================] - 1s 38ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0379 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0428
# Epoch 65/100
# 21/21 [==============================] - 1s 31ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0381 - val_loss: 0.0026 - val_mse: 0.0026 - val_mae: 0.0391
# Epoch 66/100
# 21/21 [==============================] - 1s 29ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0369 - val_loss: 0.0027 - val_mse: 0.0027 - val_mae: 0.0393
# Epoch 67/100
# 21/21 [==============================] - 1s 34ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0391 - val_loss: 0.0029 - val_mse: 0.0029 - val_mae: 0.0419
# Epoch 68/100
# 21/21 [==============================] - 1s 30ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0381 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0414
# Epoch 69/100
# 21/21 [==============================] - 1s 29ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0388 - val_loss: 0.0028 - val_mse: 0.0028 - val_mae: 0.0422
# Epoch 70/100
# 21/21 [==============================] - 1s 30ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0374 - val_loss: 0.0026 - val_mse: 0.0026 - val_mae: 0.0389
# Epoch 71/100
# 21/21 [==============================] - 1s 29ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0392 - val_loss: 0.0029 - val_mse: 0.0029 - val_mae: 0.0423
# Epoch 72/100
# 21/21 [==============================] - 1s 30ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0388 - val_loss: 0.0027 - val_mse: 0.0027 - val_mae: 0.0397
# Epoch 73/100
# 21/21 [==============================] - 1s 29ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0383 - val_loss: 0.0028 - val_mse: 0.0028 - val_mae: 0.0405
# Epoch 74/100
# 21/21 [==============================] - 1s 30ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0362 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0426
# Epoch 75/100
# 21/21 [==============================] - 1s 29ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0386 - val_loss: 0.0029 - val_mse: 0.0029 - val_mae: 0.0418
# Epoch 76/100
# 21/21 [==============================] - 1s 31ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0376 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0419
# Epoch 77/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0359 - val_loss: 0.0028 - val_mse: 0.0028 - val_mae: 0.0410
# Epoch 78/100
# 21/21 [==============================] - 1s 33ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0366 - val_loss: 0.0028 - val_mse: 0.0028 - val_mae: 0.0404
# Epoch 79/100
# 21/21 [==============================] - 0s 21ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0360 - val_loss: 0.0028 - val_mse: 0.0028 - val_mae: 0.0405
# Epoch 80/100
# 21/21 [==============================] - 0s 21ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0368 - val_loss: 0.0025 - val_mse: 0.0025 - val_mae: 0.0382
# Epoch 81/100
# 21/21 [==============================] - 1s 24ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0350 - val_loss: 0.0032 - val_mse: 0.0032 - val_mae: 0.0447
# Epoch 82/100
# 21/21 [==============================] - 0s 22ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0370 - val_loss: 0.0028 - val_mse: 0.0028 - val_mae: 0.0413
# Epoch 83/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0378 - val_loss: 0.0032 - val_mse: 0.0032 - val_mae: 0.0456
# Epoch 84/100
# 21/21 [==============================] - 0s 21ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0373 - val_loss: 0.0028 - val_mse: 0.0028 - val_mae: 0.0404
# Epoch 85/100
# 21/21 [==============================] - 0s 21ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0363 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0460
# Epoch 86/100
# 21/21 [==============================] - 0s 22ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0366 - val_loss: 0.0027 - val_mse: 0.0027 - val_mae: 0.0408
# Epoch 87/100
# 21/21 [==============================] - 1s 26ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0367 - val_loss: 0.0026 - val_mse: 0.0026 - val_mae: 0.0390
# Epoch 88/100
# 21/21 [==============================] - 1s 30ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0345 - val_loss: 0.0027 - val_mse: 0.0027 - val_mae: 0.0400
# Epoch 89/100
# 21/21 [==============================] - 1s 26ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0370 - val_loss: 0.0026 - val_mse: 0.0026 - val_mae: 0.0392
# Epoch 90/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0347 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0421
# Epoch 91/100
# 21/21 [==============================] - 1s 34ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0374 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0485
# Epoch 92/100
# 21/21 [==============================] - 1s 32ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0350 - val_loss: 0.0031 - val_mse: 0.0031 - val_mae: 0.0426
# Epoch 93/100
# 21/21 [==============================] - 1s 31ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0362 - val_loss: 0.0027 - val_mse: 0.0027 - val_mae: 0.0405
# Epoch 94/100
# 21/21 [==============================] - 1s 34ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0344 - val_loss: 0.0027 - val_mse: 0.0027 - val_mae: 0.0397
# Epoch 95/100
# 21/21 [==============================] - 1s 26ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0349 - val_loss: 0.0027 - val_mse: 0.0027 - val_mae: 0.0399
# Epoch 96/100
# 21/21 [==============================] - 1s 26ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0347 - val_loss: 0.0031 - val_mse: 0.0031 - val_mae: 0.0433
# Epoch 97/100
# 21/21 [==============================] - 0s 24ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0337 - val_loss: 0.0028 - val_mse: 0.0028 - val_mae: 0.0416
# Epoch 98/100
# 21/21 [==============================] - 1s 29ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0338 - val_loss: 0.0028 - val_mse: 0.0028 - val_mae: 0.0400
# Epoch 99/100
# 21/21 [==============================] - 0s 23ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0350 - val_loss: 0.0029 - val_mse: 0.0029 - val_mae: 0.0420
# Epoch 100/100
# 21/21 [==============================] - 0s 23ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0341 - val_loss: 0.0028 - val_mse: 0.0028 - val_mae: 0.0409

# %%
# Dự đoán

# Dự đoán train
y_pred_train=model.predict(X_train)
y_train=scaler.inverse_transform(y_train.reshape(-1,1))
y_pred_train=scaler.inverse_transform(y_pred_train.reshape(-1,1))
#Dự đoán Test
y_pred_test=model.predict(X_test)
y_test=scaler.inverse_transform(y_test.reshape(-1,1))
y_pred_test=scaler.inverse_transform(y_pred_test.reshape(-1,1))
#Dự đoán Validation
y_pred_val=model.predict(X_val)
y_val=scaler.inverse_transform(y_val.reshape(-1,1))
y_pred_val=scaler.inverse_transform(y_pred_val.reshape(-1,1))
# Out:
# 33/33 [==============================] - 2s 4ms/step
# 9/9 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 4ms/step

# %%
#Hàm visualize
def visualize(label ,pred, model_name):
  plt.figure(figsize=(12,8))
  plt.plot(label, label = 'Ground truth')
  plt.plot(pred, label='Predict')
  plt.title(model_name)
  plt.xlabel('Date')
  plt.ylabel('Closing Price')
  plt.legend()
  plt.show()

# %%
#Đánh giá 
def deviation(test, pred):
  rmse= np.sqrt(mean_squared_error(test,pred))
  print(f"RMSE: {rmse:.2f}")
  mape= mean_absolute_percentage_error(test,pred)
  print(f"MAPE: {mape*100:.2f}%")
  mae = mean_absolute_error(test, pred)
  print(f"MAE: {mae:.2f}")

# %%
# visualize(y_train,y_pred_train,'Biểu đồ dự đoán tập TRAIN')
visualize(y_test,y_pred_test,'Biểu đồ dự đoán tập TEST')
print('Đánh Giá tập TEST')
deviation(y_test, y_pred_test)
visualize(y_val,y_pred_val,'Biểu đồ dự đoán tập VALIDATION')
print('Đánh Giá tập VALIDATION')
deviation(y_val, y_pred_val)
# Out:
# Đánh Giá tập TEST
# RMSE: 38.05
# MAPE: 3.11%
# MAE: 29.60
# Đánh Giá tập VALIDATION
# RMSE: 34.79
# MAPE: 2.69%
# MAE: 27.68

# %%
# #Dự đoán 30 ngày tiếp theo
# pred_next = np.array([])
  
# y_val=y_val[-time_step:].reshape(1,-1).reshape(1,time_step)
  
# for i in range(30):
#     y_pred_next = model.predict(y_val.reshape(1,-1).reshape(1,1,time_step,1))
#     y_val = np.append(y_val,y_pred_next[0])[1:]
#     pred_next = np.append(pred_next,y_pred_next[0])
    
# next30days_predict_inverse = pd.DataFrame(scaler.inverse_transform(pred_next.reshape(-1,1)))

#Dự đoán 30 ngày tiếp theo
pred_next = np.array([])
  
y_val_to_next=scaler.fit_transform(np.array(y_val[-time_step:].reshape(1,-1).reshape(1,time_step)).reshape(-1,1))
  
for i in range(30):
    y_pred_next = model.predict(y_val_to_next.reshape(1,-1).reshape(1,1,time_step,1))
    y_val_to_next = np.append(y_val_to_next,y_pred_next[0])[1:]
    pred_next = np.append(pred_next,y_pred_next[0])
    
next30days_predict_inverse = pd.DataFrame(scaler.inverse_transform(pred_next.reshape(-1,1)))
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step

# %%
# Vẽ hình
plt.figure(figsize=(16,9))

train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(train_data_index,train_data_df)

test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index, test_data_df)

test_data_index = pd.RangeIndex(start=train_size+ 41, stop=train_size+test_size, step=1)
plt.plot(test_data_index,y_pred_test)

val_data_index = pd.RangeIndex(start=train_size + test_size, stop=train_size+test_size+val_size, step=1)
plt.plot(val_data_index, val_data_df)

val_data_index = pd.RangeIndex(start=train_size + test_size+ 41, stop=train_size+test_size+val_size, step=1)
plt.plot(val_data_index,y_pred_val)


prediect_data_index = pd.RangeIndex(start=len(df)-1, stop=len(df)+29, step=1)
plt.plot(prediect_data_index,next30days_predict_inverse)
plt.legend(['Train','Test','Predict','Validate','ValidatePred','Predict30days'])
plt.show()

# %%
from tensorflow.keras.utils import plot_model
print(model.summary())
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 1, 38, 256)       1024
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 1, 19, 256)       0
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 1, 17, 128)       98432
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 1, 8, 128)        0
#  tributed)
#
#  time_distributed_4 (TimeDis  (None, 1, 6, 64)         24640
#  tributed)
#
#  time_distributed_5 (TimeDis  (None, 1, 3, 64)         0
#  tributed)
#
#  time_distributed_6 (TimeDis  (None, 1, 192)           0
#  tributed)
#
#  bidirectional (Bidirectiona  (None, 1, 200)           234400
#  l)
#
#  dropout (Dropout)           (None, 1, 200)            0
#
#  bidirectional_1 (Bidirectio  (None, 200)              240800
#  nal)
#
#  dropout_1 (Dropout)         (None, 200)               0
#
#  dense (Dense)               (None, 1)                 201
#
# =================================================================
# Total params: 599,497
# Trainable params: 599,497
# Non-trainable params: 0
# _________________________________________________________________
# None
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.
