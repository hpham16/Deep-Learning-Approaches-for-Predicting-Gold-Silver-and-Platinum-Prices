# %% [markdown]
# # IS403.N22.HTCL
# ```python
# Team 16
# ```
# **SỬ DỤNG ĐỂ TÍNH TOÁN BỘ DỮ LIỆU GIÁ VÀNG (19/05/2018 ĐẾN 19/05/2023)**
# - Tỷ lệ tính toán Train Data: 60% Dataset
# - Tỷ lệ tính toán Test Data: 30% Dataset
# - Tỷ lệ tính toán Validation Data: 10% Dataset

# %%
#Import các thư viện cần thiết
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from sklearn import preprocessing
from keras.layers import Conv1D,Flatten,MaxPooling1D,Bidirectional,LSTM,Dropout,TimeDistributed
from keras.layers import Dense,GlobalAveragePooling2D
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error,mean_absolute_error

# %%
#Đọc file dữ liệu và xem dữ liệu
df = pd.read_csv('../GoldData.csv',parse_dates=True)
df
# Out:
#            Ngày  Lần cuối      Mở     Cao    Thấp       KL
# 0     21/5/2018    1290.9  1290.3  1292.7  1281.2  328.02K
# 1     22/5/2018    1292.0  1292.3  1296.0  1287.2  291.72K
# 2     23/5/2018    1289.6  1290.6  1298.4  1286.7  402.34K
# 3     24/5/2018    1304.4  1293.3  1306.4  1292.2  432.42K
# 4     25/5/2018    1303.7  1304.0  1307.2  1299.4  292.91K
# ...         ...       ...     ...     ...     ...      ...
# 1291  15/5/2023    2018.0  2013.8  2017.1  2013.8    0.00K
# 1292  16/5/2023    1988.4  2021.3  2022.7  1989.1    0.05K
# 1293  17/5/2023    1980.7  1983.6  1983.6  1983.6    0.01K
# 1294  18/5/2023    1956.5  1956.8  1956.8  1956.8    0.02K
# 1295  19/5/2023    1978.7  1960.0  1976.7  1960.0    0.11K
#
# [1296 rows x 6 columns]

# %%
#Xem các dữ liệu cơ bản của cảc thuộc tính
df.describe()
# Out:
#           Lần cuối           Mở          Cao         Thấp
# count  1296.000000  1296.000000  1296.000000  1296.000000
# mean   1657.157253  1657.419946  1668.953858  1645.013889
# std     247.037374   247.289166   250.206107   243.663453
# min    1184.000000  1180.700000  1189.000000  1167.100000
# 25%    1467.675000  1465.800000  1473.625000  1459.100000
# 50%    1751.750000  1751.550000  1761.200000  1735.750000
# 75%    1841.325000  1840.725000  1853.300000  1828.425000
# max    2069.400000  2076.400000  2089.200000  2049.000000

# %%
#Kiểm tra dữ liệu rỗng
df.isnull().sum()
# Out:
# Ngày        0
# Lần cuối    0
# Mở          0
# Cao         0
# Thấp        0
# KL          6
# dtype: int64

# %%
#Xem độ biến thiên của từng thuộc tính.
df.plot(legend=True,subplots=True, figsize = (16, 9))
plt.show()

# %%
#Chuyển dataset về cột Close để tiến hành tạo model
df = df[['Lần cuối']]
df
# Out:
#       Lần cuối
# 0       1290.9
# 1       1292.0
# 2       1289.6
# 3       1304.4
# 4       1303.7
# ...        ...
# 1291    2018.0
# 1292    1988.4
# 1293    1980.7
# 1294    1956.5
# 1295    1978.7
#
# [1296 rows x 1 columns]

# %%
#Chia dữ liệu theo các tỷ lệ 7:2:1
train_size = int(0.6 * len(df))
test_size = int(0.3 * len(df))
val_size = len(df) - train_size - test_size

train_data_df = df[:train_size]
test_data_df = df[train_size:train_size+test_size]
val_data_df = df[train_size+test_size:]

# %%
# Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df=scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
#Chia data đã Scaler
train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]

# %%
#Tạo hàm create dataset
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return np.array(dataX),np.array(dataY)

# %%
#Chia thành các tập X,y
time_step = 40
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)
X_val, y_val = create_dataset(val_data, time_step)

# %%
# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],1, X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1] , 1)
X_val = X_val.reshape(X_val.shape[0],1 ,X_val.shape[1] , 1)

# %% [markdown]
# Vì thuật toán Hybird Neural Netword là sự kết hợp của các loại mạng neural khác nhau nên ở đây em kết hợp 2 mạng neural đã học là:
# - Mạng neural hồi quy LSTM
# - Mạng neural tích nhập CNN
#
# Cụ thể thì các lớp CNN được sử dụng để trích xuất đặc trưng từ dữ liệu không gian hoặc hình ảnh. Sau đó, các đặc trưng này được biến đổi và truyền vào các lớp LSTM. Các lớp LSTM có khả năng xử lý dữ liệu chuỗi thời gian và tạo ra dự đoán hoặc phân loại dựa trên thông tin này.

# %%
#Tiến hành tạo model
import tensorflow as tf
import tensorflow.keras.backend as K 
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, Bidirectional, TimeDistributed
from tensorflow.keras.layers import MaxPooling1D, Flatten
from tensorflow.keras.regularizers import L1, L2
from tensorflow.keras.metrics import Accuracy
from tensorflow.keras.metrics import RootMeanSquaredError 
from tensorflow.keras.utils import plot_model

model = tf.keras.Sequential()

# CNN layers
model.add(TimeDistributed(Conv1D(256, kernel_size=3, activation='relu', input_shape=(None, 50 , 1))))
model.add(TimeDistributed(MaxPooling1D(2)))
model.add(TimeDistributed(Conv1D(128, kernel_size=3, activation='relu')))
model.add(TimeDistributed(MaxPooling1D(2)))
model.add(TimeDistributed(Conv1D(64, kernel_size=3, activation='relu')))
model.add(TimeDistributed(MaxPooling1D(2)))
model.add(TimeDistributed(Flatten()))

# LSTM layers
model.add(Bidirectional(LSTM(100, return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(100, return_sequences=False)))
model.add(Dropout(0.5))

#Final layers
model.add(Dense(1, activation='linear'))
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mse', 'mae'])

#fit model
history = model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=100,batch_size=50, verbose=1, shuffle =True)
# Out:
# Epoch 1/100
# 15/15 [==============================] - 9s 108ms/step - loss: 0.1190 - mse: 0.1190 - mae: 0.2649 - val_loss: 0.0257 - val_mse: 0.0257 - val_mae: 0.1466
# Epoch 2/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0230 - mse: 0.0230 - mae: 0.1205 - val_loss: 0.0050 - val_mse: 0.0050 - val_mae: 0.0569
# Epoch 3/100
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0110 - mse: 0.0110 - mae: 0.0792 - val_loss: 0.0041 - val_mse: 0.0041 - val_mae: 0.0509
# Epoch 4/100
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0078 - mse: 0.0078 - mae: 0.0644 - val_loss: 0.0042 - val_mse: 0.0042 - val_mae: 0.0514
# Epoch 5/100
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0068 - mse: 0.0068 - mae: 0.0604 - val_loss: 0.0037 - val_mse: 0.0037 - val_mae: 0.0472
# Epoch 6/100
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0070 - mse: 0.0070 - mae: 0.0586 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0466
# Epoch 7/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0064 - mse: 0.0064 - mae: 0.0580 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0464
# Epoch 8/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0067 - mse: 0.0067 - mae: 0.0596 - val_loss: 0.0050 - val_mse: 0.0050 - val_mae: 0.0561
# Epoch 9/100
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0064 - mse: 0.0064 - mae: 0.0569 - val_loss: 0.0038 - val_mse: 0.0038 - val_mae: 0.0488
# Epoch 10/100
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0062 - mse: 0.0062 - mae: 0.0560 - val_loss: 0.0040 - val_mse: 0.0040 - val_mae: 0.0503
100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0402 - val_loss: 0.0026 - val_mse: 0.0026 - val_mae: 0.0405
# Epoch 52/100
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0392 - val_loss: 0.0023 - val_mse: 0.0023 - val_mae: 0.0386
# Epoch 53/100
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0399 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0451
# Epoch 54/100
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0401 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0362
# Epoch 55/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0424 - val_loss: 0.0029 - val_mse: 0.0029 - val_mae: 0.0441
# Epoch 56/100
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0392 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0363
# Epoch 57/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0387 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0357
# Epoch 58/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0405 - val_loss: 0.0023 - val_mse: 0.0023 - val_mae: 0.0377
# Epoch 59/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0406 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0366
# Epoch 60/100
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0388 - val_loss: 0.0026 - val_mse: 0.0026 - val_mae: 0.0410
# Epoch 61/100
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0391 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0366
# Epoch 62/100
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0454 - val_loss: 0.0023 - val_mse: 0.0023 - val_mae: 0.0381
# Epoch 63/100
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0399 - val_loss: 0.0033 - val_mse: 0.0033 - val_mae: 0.0475
# Epoch 64/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0412 - val_loss: 0.0026 - val_mse: 0.0026 - val_mae: 0.0416
# Epoch 65/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0378 - val_loss: 0.0022 - val_mse: 0.0022 - val_mae: 0.0373
# Epoch 66/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0382 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0352
# Epoch 67/100
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0400 - val_loss: 0.0023 - val_mse: 0.0023 - val_mae: 0.0384
# Epoch 68/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0411 - val_loss: 0.0062 - val_mse: 0.0062 - val_mae: 0.0682
# Epoch 69/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0445 - val_loss: 0.0029 - val_mse: 0.0029 - val_mae: 0.0433
# Epoch 70/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0398 - val_loss: 0.0026 - val_mse: 0.0026 - val_mae: 0.0415
# Epoch 71/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0372 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0357
# Epoch 72/100
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0374 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0359
# Epoch 73/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0384 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0351
# Epoch 74/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0377 - val_loss: 0.0022 - val_mse: 0.0022 - val_mae: 0.0370
# Epoch 75/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0386 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0447
# Epoch 76/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0391 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0491
# Epoch 77/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0401 - val_loss: 0.0035 - val_mse: 0.0035 - val_mae: 0.0488
# Epoch 78/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0389 - val_loss: 0.0022 - val_mse: 0.0022 - val_mae: 0.0375
# Epoch 79/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0382 - val_loss: 0.0047 - val_mse: 0.0047 - val_mae: 0.0580
# Epoch 80/100
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0386 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0357
# Epoch 81/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0377 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0356
# Epoch 82/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0374 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0350
# Epoch 83/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0366 - val_loss: 0.0033 - val_mse: 0.0033 - val_mae: 0.0466
# Epoch 84/100
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0388 - val_loss: 0.0024 - val_mse: 0.0024 - val_mae: 0.0390
# Epoch 85/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0371 - val_loss: 0.0026 - val_mse: 0.0026 - val_mae: 0.0406
# Epoch 86/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0380 - val_loss: 0.0023 - val_mse: 0.0023 - val_mae: 0.0386
# Epoch 87/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0398 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0364
# Epoch 88/100
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0389 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0347
# Epoch 89/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0374 - val_loss: 0.0026 - val_mse: 0.0026 - val_mae: 0.0400
# Epoch 90/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0378 - val_loss: 0.0022 - val_mse: 0.0022 - val_mae: 0.0367
# Epoch 91/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0357 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0349
# Epoch 92/100
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0357 - val_loss: 0.0024 - val_mse: 0.0024 - val_mae: 0.0380
# Epoch 93/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0385 - val_loss: 0.0023 - val_mse: 0.0023 - val_mae: 0.0374
# Epoch 94/100
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0377 - val_loss: 0.0024 - val_mse: 0.0024 - val_mae: 0.0397
# Epoch 95/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0416 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0476
# Epoch 96/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0385 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0366
# Epoch 97/100
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0362 - val_loss: 0.0022 - val_mse: 0.0022 - val_mae: 0.0368
# Epoch 98/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0361 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0359
# Epoch 99/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0386 - val_loss: 0.0048 - val_mse: 0.0048 - val_mae: 0.0579
# Epoch 100/100
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0375 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0344

# %%
# Dự đoán

# Dự đoán train
y_pred_train=model.predict(X_train)
y_train=scaler.inverse_transform(y_train.reshape(-1,1))
y_pred_train=scaler.inverse_transform(y_pred_train.reshape(-1,1))
#Dự đoán Test
y_pred_test=model.predict(X_test)
y_test=scaler.inverse_transform(y_test.reshape(-1,1))
y_pred_test=scaler.inverse_transform(y_pred_test.reshape(-1,1))
#Dự đoán Validation
y_pred_val=model.predict(X_val)
y_val=scaler.inverse_transform(y_val.reshape(-1,1))
y_pred_val=scaler.inverse_transform(y_pred_val.reshape(-1,1))
# Out:
# 23/23 [==============================] - 1s 4ms/step
# 11/11 [==============================] - 2s 5ms/step
# 3/3 [==============================] - 0s 4ms/step

# %%
#Hàm visualize
def visualize(label ,pred, model_name):
  plt.figure(figsize=(12,8))
  plt.plot(label, label = 'Ground truth')
  plt.plot(pred, label='Predict')
  plt.title(model_name)
  plt.xlabel('Date')
  plt.ylabel('Closing Price')
  plt.legend()
  plt.show()

# %%
#Đánh giá 
def deviation(test, pred):
  rmse= np.sqrt(mean_squared_error(test,pred))
  print(f"RMSE: {rmse:.2f}")
  mape= mean_absolute_percentage_error(test,pred)
  print(f"MAPE: {mape*100:.2f}%")
  mae = mean_absolute_error(test, pred)
  print(f"MAE: {mae:.2f}")

# %%
# visualize(y_train,y_pred_train,'Biểu đồ dự đoán tập TRAIN')
visualize(y_test,y_pred_test,'Biểu đồ dự đoán tập TEST')
print('Đánh Giá tập TEST')
deviation(y_test, y_pred_test)
visualize(y_val,y_pred_val,'Biểu đồ dự đoán tập VALIDATION')
print('Đánh Giá tập VALIDATION')
deviation(y_val, y_pred_val)
# Out:
# Đánh Giá tập TEST
# RMSE: 38.43
# MAPE: 1.70%
# MAE: 30.49
# Đánh Giá tập VALIDATION
# RMSE: 56.18
# MAPE: 2.27%
# MAE: 44.58

# %%
# #Dự đoán 30 ngày tiếp theo
# pred_next = np.array([])
  
# y_val=y_val[-time_step:].reshape(1,-1).reshape(1,time_step)
  
# for i in range(30):
#     y_pred_next = model.predict(y_val.reshape(1,-1).reshape(1,1,time_step,1))
#     y_val = np.append(y_val,y_pred_next[0])[1:]
#     pred_next = np.append(pred_next,y_pred_next[0])
    
# next30days_predict_inverse = pd.DataFrame(scaler.inverse_transform(pred_next.reshape(-1,1)))

#Dự đoán 30 ngày tiếp theo
pred_next = np.array([])
  
y_val_to_next=scaler.fit_transform(np.array(y_val[-time_step:].reshape(1,-1).reshape(1,time_step)).reshape(-1,1))
  
for i in range(30):
    y_pred_next = model.predict(y_val_to_next.reshape(1,-1).reshape(1,1,time_step,1))
    y_val_to_next = np.append(y_val_to_next,y_pred_next[0])[1:]
    pred_next = np.append(pred_next,y_pred_next[0])
    
next30days_predict_inverse = pd.DataFrame(scaler.inverse_transform(pred_next.reshape(-1,1)))
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 52ms/step

# %%
# Vẽ hình
plt.figure(figsize=(16,9))

train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(train_data_index,train_data_df)

test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index, test_data_df)

test_data_index = pd.RangeIndex(start=train_size+ 41, stop=train_size+test_size, step=1)
plt.plot(test_data_index,y_pred_test)

val_data_index = pd.RangeIndex(start=train_size + test_size, stop=train_size+test_size+val_size, step=1)
plt.plot(val_data_index, val_data_df)

val_data_index = pd.RangeIndex(start=train_size + test_size+ 41, stop=train_size+test_size+val_size, step=1)
plt.plot(val_data_index,y_pred_val)


prediect_data_index = pd.RangeIndex(start=len(df)-1, stop=len(df)+29, step=1)
plt.plot(prediect_data_index,next30days_predict_inverse)
plt.legend(['Train','Test','Predict','Validate','ValidatePred','Predict30days'])
plt.show()

# %%
from tensorflow.keras.utils import plot_model
print(model.summary())
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 1, 38, 256)       1024
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 1, 19, 256)       0
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 1, 17, 128)       98432
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 1, 8, 128)        0
#  tributed)
#
#  time_distributed_4 (TimeDis  (None, 1, 6, 64)         24640
#  tributed)
#
#  time_distributed_5 (TimeDis  (None, 1, 3, 64)         0
#  tributed)
#
#  time_distributed_6 (TimeDis  (None, 1, 192)           0
#  tributed)
#
#  bidirectional (Bidirectiona  (None, 1, 200)           234400
#  l)
#
#  dropout (Dropout)           (None, 1, 200)            0
#
#  bidirectional_1 (Bidirectio  (None, 200)              240800
#  nal)
#
#  dropout_1 (Dropout)         (None, 200)               0
#
#  dense (Dense)               (None, 1)                 201
#
# =================================================================
# Total params: 599,497
# Trainable params: 599,497
# Non-trainable params: 0
# _________________________________________________________________
# None
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.
