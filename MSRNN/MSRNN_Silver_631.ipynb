# %% [markdown]
# # IS403.N22.HTCL
# ```python
# Team 16
# ```
# **SỬ DỤNG ĐỂ TÍNH TOÁN BỘ DỮ LIỆU GIÁ BẠC (19/05/2018 ĐẾN 19/05/2023)**
# - Tỷ lệ tính toán Train Data: 60% Dataset
# - Tỷ lệ tính toán Test Data: 30% Dataset
# - Tỷ lệ tính toán Validation Data: 10% Dataset

# %%
#Import các thư viện cần thiết
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from sklearn import preprocessing
from keras.layers import Conv1D,Flatten,MaxPooling1D,Bidirectional,LSTM,Dropout,TimeDistributed
from keras.layers import Dense,GlobalAveragePooling2D
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error,mean_absolute_error

# %%
#Đọc file dữ liệu và xem dữ liệu
df = pd.read_csv('../SilverData.csv',parse_dates=True)
df
# Out:
#            Ngày  Lần cuối      Mở     Cao    Thấp      KL
# 0     21/5/2018    16.520  16.430  16.535  16.280  63.89K
# 1     22/5/2018    16.575  16.530  16.700  16.465  73.53K
# 2     23/5/2018    16.405  16.555  16.600  16.330  89.46K
# 3     24/5/2018    16.687  16.475  16.715  16.420  91.02K
# 4     25/5/2018    16.546  16.690  16.740  16.500  72.71K
# ...         ...       ...     ...     ...     ...     ...
# 1275  15/5/2023    24.175  24.030  24.270  23.945   0.17K
# 1276  16/5/2023    23.783  24.115  24.115  23.710   0.18K
# 1277  17/5/2023    23.789  23.830  23.940  23.650   0.18K
# 1278  18/5/2023    23.523  23.840  23.840  23.380   0.35K
# 1279  19/5/2023    23.948  23.560  24.010  23.555   0.15K
#
# [1280 rows x 6 columns]

# %%
#Xem các dữ liệu cơ bản của cảc thuộc tính
df.describe()
# Out:
#           Lần cuối           Mở          Cao         Thấp
# count  1280.000000  1280.000000  1280.000000  1280.000000
# mean     20.414323    20.428459    20.685217    20.134988
# std       4.325552     4.335049     4.437082     4.203927
# min      11.772000    11.975000    12.330000    11.640000
# 25%      16.223000    16.252500    16.388750    16.080000
# 50%      20.350500    20.312500    20.762500    19.987500
# 75%      24.250750    24.251250    24.580000    23.872500
# max      29.418000    29.235000    30.350000    28.155000

# %%
#Kiểm tra dữ liệu rỗng
df.isnull().sum()
# Out:
# Ngày         0
# Lần cuối     0
# Mở           0
# Cao          0
# Thấp         0
# KL          28
# dtype: int64

# %%
#Xem độ biến thiên của từng thuộc tính.
df.plot(legend=True,subplots=True, figsize = (16, 9))
plt.show()

# %%
#Chuyển dataset về cột Close để tiến hành tạo model
df = df[['Lần cuối']]
df
# Out:
#       Lần cuối
# 0       16.520
# 1       16.575
# 2       16.405
# 3       16.687
# 4       16.546
# ...        ...
# 1275    24.175
# 1276    23.783
# 1277    23.789
# 1278    23.523
# 1279    23.948
#
# [1280 rows x 1 columns]

# %%
#Chia dữ liệu theo các tỷ lệ 7:2:1
train_size = int(0.6 * len(df))
test_size = int(0.3 * len(df))
val_size = len(df) - train_size - test_size

train_data_df = df[:train_size]
test_data_df = df[train_size:train_size+test_size]
val_data_df = df[train_size+test_size:]

# %%
# Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df=scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
#Chia data đã Scaler
train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]

# %%
#Tạo hàm create dataset
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	
_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1] , 1)
# X_val = X_val.reshape(X_val.shape[0],1 ,X_val.shape[1] , 1)

# %%
import tensorflow as tf
from tensorflow.keras import layers

class DilatedGRUCell(layers.Layer):
    def __init__(self, units, dilation_rate=1, **kwargs):
        super(DilatedGRUCell, self).__init__(**kwargs)
        self.units = units
        self.dilation_rate = dilation_rate
        self.state_size = units
        self.gru_cell = layers.GRUCell(units)
        
    def call(self, inputs, states):
        # Apply dilation to the input sequence
        inputs = inputs[:, ::self.dilation_rate]
        
        # Pass the dilated input sequence to the GRU cell
        outputs, new_states = self.gru_cell(inputs, states)
        
        return outputs, new_states

# Define the number of units in each layer
num_units = 16

# Define the input shape
input_shape = (None, 1)

# Create the input layer
inputs = layers.Input(input_shape)

# Create the first dilated RNN layer with a dilation rate of 1
x = layers.RNN(
    DilatedGRUCell(num_units, dilation_rate=1),
    return_sequences=False,
)(inputs)

# Create the second dilated RNN layer with a dilation rate of 2
x = layers.RNN(
    DilatedGRUCell(num_units, dilation_rate=2),
    return_sequences=False,  # Set return_sequences to False for the last layer
)(x[:, :, tf.newaxis])  # Add an extra dimension to the input

# Create the output layer
outputs = layers.Dense(1)(x)

# Create the model
model = tf.keras.Model(inputs=inputs, outputs=outputs)

#Final layers
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mse', 'mae'])

#fit model
history = model.fit(
    X_train,
    y_train,
    validation_data=(X_test,y_test),
    batch_size=32,
    epochs=40
)
# Out:
# Epoch 1/40
# 23/23 [==============================] - 4s 46ms/step - loss: 0.1431 - mse: 0.1431 - mae: 0.2853 - val_loss: 0.1075 - val_mse: 0.1075 - val_mae: 0.3069
# Epoch 2/40
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0550 - mse: 0.0550 - mae: 0.2025 - val_loss: 0.0156 - val_mse: 0.0156 - val_mae: 0.1073
# Epoch 3/40
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0360 - mse: 0.0360 - mae: 0.1710 - val_loss: 0.0095 - val_mse: 0.0095 - val_mae: 0.0818
# Epoch 4/40
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0111 - mse: 0.0111 - mae: 0.0867 - val_loss: 0.0061 - val_mse: 0.0061 - val_mae: 0.0640
# Epoch 5/40
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0352 - val_loss: 0.0093 - val_mse: 0.0093 - val_mae: 0.0821
# Epoch 6/40
# 23/23 [==============================] - 1s 23ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0329 - val_loss: 0.0069 - val_mse: 0.0069 - val_mae: 0.0701
# Epoch 7/40
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0317 - val_loss: 0.0081 - val_mse: 0.0081 - val_mae: 0.0777
# Epoch 8/40
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0304 - val_loss: 0.0090 - val_mse: 0.0090 - val_mae: 0.0832
# Epoch 9/40
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0302 - val_loss: 0.0067 - val_mse: 0.0067 - val_mae: 0.0707
# Epoch 10/40
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0293 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0597
# Epoch 11/40
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0282 - val_loss: 0.0040 - val_mse: 0.0040 - val_mae: 0.0528
# Epoch 12/40
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0282 - val_loss: 0.0041 - val_mse: 0.0041 - val_mae: 0.0542
# Epoch 13/40
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0269 - val_loss: 0.0041 - val_mse: 0.0041 - val_mae: 0.0544
# Epoch 14/40
# 23/23 [==============================] - 0s 22ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0271 - val_loss: 0.0042 - val_mse: 0.0042 - val_mae: 0.0554
# Epoch 15/40
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0267 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0330
# Epoch 16/40
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0270 - val_loss: 0.0029 - val_mse: 0.0029 - val_mae: 0.0442
# Epoch 17/40
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0268 - val_loss: 0.0033 - val_mse: 0.0033 - val_mae: 0.0481
# Epoch 18/40
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0247 - val_loss: 0.0028 - val_mse: 0.0028 - val_mae: 0.0433
# Epoch 19/40
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0245 - val_loss: 0.0025 - val_mse: 0.0025 - val_mae: 0.0402
# Epoch 20/40
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0246 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0358
# Epoch 21/40
# 23/23 [==============================] - 0s 22ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0243 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0343
# Epoch 22/40
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0244 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0362
# Epoch 23/40
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0234 - val_loss: 0.0022 - val_mse: 0.0022 - val_mae: 0.0371
# Epoch 24/40
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0235 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0330
# Epoch 25/40
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0229 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0364
# Epoch 26/40
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0227 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0329
# Epoch 27/40
# 23/23 [==============================] - 0s 17ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0233 - val_loss: 0.0024 - val_mse: 0.0024 - val_mae: 0.0400
# Epoch 28/40
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0234 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0304
# Epoch 29/40
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0231 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0303
# Epoch 30/40
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0225 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0356
# Epoch 31/40
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0226 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0295
# Epoch 32/40
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0229 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0293
# Epoch 33/40
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0226 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0296
# Epoch 34/40
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0227 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0295
# Epoch 35/40
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0218 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0280
# Epoch 36/40
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0220 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0283
# Epoch 37/40
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0221 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0282
# Epoch 38/40
# 23/23 [==============================] - 0s 16ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0219 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0337
# Epoch 39/40
# 23/23 [==============================] - 0s 16ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0225 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0279
# Epoch 40/40
# 23/23 [==============================] - 0s 15ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0214 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0350

# %%
# Dự đoán

# Dự đoán train
y_pred_train=model.predict(X_train)
y_train=scaler.inverse_transform(y_train.reshape(-1,1))
y_pred_train=scaler.inverse_transform(y_pred_train.reshape(-1,1))
#Dự đoán Test
y_pred_test=model.predict(X_test)
y_test=scaler.inverse_transform(y_test.reshape(-1,1))
y_pred_test=scaler.inverse_transform(y_pred_test.reshape(-1,1))
#Dự đoán Validation
y_pred_val=model.predict(X_val)
y_val=scaler.inverse_transform(y_val.reshape(-1,1))
y_pred_val=scaler.inverse_transform(y_pred_val.reshape(-1,1))
# Out:
# 23/23 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 3ms/step
# 3/3 [==============================] - 0s 3ms/step

# %%
# Print the length
print(y_pred_test.shape[0])
print(y_test.shape[0])
print(y_pred_train.shape[0])
print(y_train.shape[0])
# Out:
# 343
# 343
# 727
# 727

# %%
#Hàm visualize
def visualize(label ,pred, model_name):
  plt.figure(figsize=(12,8))
  plt.plot(label, label = 'Ground truth')
  plt.plot(pred, label='Predict')
  plt.title(model_name)
  plt.xlabel('Date')
  plt.ylabel('Closing Price')
  plt.legend()
  plt.show()

# %%
#8. Đánh giá 
def deviation(test, pred):
  rmse= np.sqrt(mean_squared_error(test,pred))
  print(f"RMSE: {rmse:.2f}")
  mape= mean_absolute_percentage_error(test,pred)
  print(f"MAPE: {mape*100:.2f}%")
  mae = mean_absolute_error(test, pred)
  print(f"MAE: {mae:.2f}")

# %%
# visualize(y_train,y_pred_train,'Biểu đồ dự đoán tập TRAIN')
visualize(y_test,y_pred_test,'Biểu đồ dự đoán tập TEST')
print('Đánh Giá tập TEST')
deviation(y_test, y_pred_test)
visualize(y_val,y_pred_val,'Biểu đồ dự đoán tập VALIDATION')
print('Đánh Giá tập VALIDATION')
deviation(y_val, y_pred_val)
# Out:
# Đánh Giá tập TEST
# RMSE: 0.77
# MAPE: 2.81%
# MAE: 0.62
# Đánh Giá tập VALIDATION
# RMSE: 0.75
# MAPE: 2.69%
# MAE: 0.61

# %%
#Dự đoán 30 ngày tiếp theo
pred_next = np.array([])
  
y_val_to_next=scaler.fit_transform(np.array(y_val[-time_step:].reshape(1,-1).reshape(1,time_step)).reshape(-1,1))
  
for i in range(30):
    print(y_val_to_next)
    y_pred_next = model.predict(y_val_to_next.reshape(1,-1))
    y_val_to_next = np.append(y_val_to_next,y_pred_next[0])[1:]
    pred_next = np.append(pred_next,y_pred_next[0])
    
next30days_predict_inverse = pd.DataFrame(scaler.inverse_transform(pred_next.reshape(-1,1)))
# Out:
# [[0.02101736]
#  [0.05239111]
#  [0.        ]
#  [0.08224185]
#  [0.09625343]
#  [0.2784039 ]
#  [0.32927201]
#  [0.28815108]
#  [0.61711849]
#  [0.59762412]
#  [0.61468169]
#  [0.55954919]
#  [0.64300944]
#  [0.72586049]
#  [0.86810844]
#  [0.72646969]
#  [0.6131587 ]
#  [0.73378008]
#  [0.76606762]
#  [0.76759062]
#  [0.67164179]
#  [0.74596406]
#  [0.6131587 ]
#  [0.60798051]
#  [0.65001523]
#  [0.65519342]
#  [0.65641182]
#  [0.77490101]
#  [0.79378617]
#  [1.        ]
#  [0.86963143]
#  [0.84038989]
#  [0.85988425]
#  [0.78678038]
#  [0.41090466]
#  [0.32866281]
#  [0.3350594 ]
#  [0.21565641]
#  [0.21748401]
#  [0.13646055]]
# 1/1 [==============================] - 0s 28ms/step
# [0.05239111 0.         0.08224185 0.09625343 0.2784039  0.32927201
#  0.28815108 0.61711849 0.59762412 0.61468169 0.55954919 0.64300944
#  0.72586049 0.86810844 0.72646969 0.6131587  0.73378008 0.76606762
#  0.76759062 0.67164179 0.74596406 0.6131587  0.60798051 0.65001523
#  0.65519342 0.65641182 0.77490101 0.79378617 1.         0.86963143
#  0.84038989 0.85988425 0.78678038 0.41090466 0.32866281 0.3350594
#  0.21565641 0.21748401 0.13646055 0.2458647 ]
# 1/1 [==============================] - 0s 21ms/step
# [0.         0.08224185 0.09625343 0.2784039  0.32927201 0.28815108
#  0.61711849 0.59762412 0.61468169 0.55954919 0.64300944 0.72586049
#  0.86810844 0.72646969 0.6131587  0.73378008 0.76606762 0.76759062
#  0.67164179 0.74596406 0.6131587  0.60798051 0.65001523 0.65519342
#  0.65641182 0.77490101 0.79378617 1.         0.86963143 0.84038989
#  0.85988425 0.78678038 0.41090466 0.32866281 0.3350594  0.21565641
#  0.21748401 0.13646055 0.2458647  0.21844351]
# 1/1 [==============================] - 0s 20ms/step
# [0.08224185 0.09625343 0.2784039  0.32927201 0.28815108 0.61711849
#  0.59762412 0.61468169 0.55954919 0.64300944 0.72586049 0.86810844
#  0.72646969 0.6131587  0.73378008 0.76606762 0.76759062 0.67164179
#  0.74596406 0.6131587  0.60798051 0.65001523 0.65519342 0.65641182
#  0.77490101 0.79378617 1.         0.86963143 0.84038989 0.85988425
#  0.78678038 0.41090466 0.32866281 0.3350594  0.21565641 0.21748401
#  0.13646055 0.2458647  0.21844351 0.21498805]
# 1/1 [==============================] - 0s 20ms/step
# [0.09625343 0.2784039  0.32927201 0.28815108 0.61711849 0.59762412
#  0.61468169 0.55954919 0.64300944 0.72586049 0.86810844 0.72646969
#  0.23717171 0.2398048  0.24242648 0.24503881 0.24764405 0.25024429
#  0.2528418  0.25543872 0.25803712 0.26063925 0.26324713 0.26586303
#  0.26848906 0.27112722 0.27377993 0.27644923]
# 1/1 [==============================] - 0s 19ms/step
# [0.79378617 1.         0.86963143 0.84038989 0.85988425 0.78678038
#  0.41090466 0.32866281 0.3350594  0.21565641 0.21748401 0.13646055
#  0.2458647  0.21844351 0.21498805 0.21628918 0.21858887 0.22115557
#  0.22381487 0.22650206 0.22918889 0.23186439 0.23452541 0.23717171
#  0.2398048  0.24242648 0.24503881 0.24764405 0.25024429 0.2528418
#  0.25543872 0.25803712 0.26063925 0.26324713 0.26586303 0.26848906
#  0.27112722 0.27377993 0.27644923 0.2791374 ]
# 1/1 [==============================] - 0s 18ms/step
# [1.         0.86963143 0.84038989 0.85988425 0.78678038 0.41090466
#  0.32866281 0.3350594  0.21565641 0.21748401 0.13646055 0.2458647
#  0.21844351 0.21498805 0.21628918 0.21858887 0.22115557 0.22381487
#  0.22650206 0.22918889 0.23186439 0.23452541 0.23717171 0.2398048
#  0.24242648 0.24503881 0.24764405 0.25024429 0.2528418  0.25543872
#  0.25803712 0.26063925 0.26324713 0.26586303 0.26848906 0.27112722
#  0.27377993 0.27644923 0.2791374  0.2818467 ]
# 1/1 [==============================] - 0s 19ms/step

# %%
next30days_predict_inverse
# Out:
#             0
# 0   23.882174
# 1   23.792150
# 2   23.780806
# 3   23.785077
# 4   23.792627
# 5   23.801054
# 6   23.809784
# 7   23.818606
# 8   23.827427
# 9   23.836211
# 10  23.844947
# 11  23.853635
# 12  23.862279
# 13  23.870886
# 14  23.879462
# 15  23.888015
# 16  23.896552
# 17  23.905080
# 18  23.913605
# 19  23.922136
# 20  23.930679
# 21  23.939240
# 22  23.947828
# 23  23.956450
# 24  23.965111
# 25  23.973820
# 26  23.982583
# 27  23.991408
# 28  24.000303
# 29  24.009275

# %%
# Vẽ hình
plt.figure(figsize=(16,9))

train_data_index = pd.RangeIndex(start=train_size-100, stop=train_size, step=1)
plt.plot(train_data_index,train_data_df[train_size-100:])

test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index, test_data_df)

test_data_index = pd.RangeIndex(start=train_size+ 41, stop=train_size+test_size, step=1)
plt.plot(test_data_index,y_pred_test)

val_data_index = pd.RangeIndex(start=train_size + test_size, stop=train_size+test_size+val_size, step=1)
plt.plot(val_data_index, val_data_df)

val_data_index = pd.RangeIndex(start=train_size + test_size+ 41, stop=train_size+test_size+val_size, step=1)
plt.plot(val_data_index,y_pred_val)


prediect_data_index = pd.RangeIndex(start=len(df)-1, stop=len(df)+29, step=1)
plt.plot(prediect_data_index,next30days_predict_inverse)

plt.legend(['Train','Test','Predict','Validate','ValidatePred','Predict30days'])
plt.show()

# %%
from tensorflow.keras.utils import plot_model
print(model.summary())
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, 1)]         0
#
#  rnn (RNN)                   (None, 16)                912
#
#  tf.__operators__.getitem (S  (None, 16, 1)            0
#  licingOpLambda)
#
#  rnn_1 (RNN)                 (None, 16)                912
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 1,841
# Trainable params: 1,841
# Non-trainable params: 0
# _________________________________________________________________
# None
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.
